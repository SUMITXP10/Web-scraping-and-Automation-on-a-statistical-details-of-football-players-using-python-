# %% [markdown]
# # **WEB SCRAPING DATASET URL LINK : https://sofifa.com/players**
#
# # **WEB SCRAPING DATASET [ CSV ] LINK : https://raw.githubusercontent.com/SUMITXP10/WEB-SCRAPING-AND-AUTOMATION-USING-PYTHON-BOOTCAMP-PROJECT-CSV-FILE-01/main/sumitfifa.csv**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests as rq
from time import sleep
from random import randint
from bs4 import BeautifulSoup

# %% [markdown]
# # **10 Pages :**

# %% [markdown]
# # **1st Page :**
#
# https://sofifa.com/players
#
# # **OR**
#
# https://sofifa.com/players?offset=0

# %% [markdown]
# # **2nd Page :**
#
# https://sofifa.com/players?offset=60

# %% [markdown]
# # **3rd Page :**
#
# https://sofifa.com/players?offset=120

# %% [markdown]
# # **4th Page :**
#
# https://sofifa.com/players?offset=180

# %% [markdown]
# # **5th Page :**
#
# https://sofifa.com/players?offset=240

# %% [markdown]
# # **6th Page :**
#
# https://sofifa.com/players?offset=300

# %% [markdown]
# # **7th Page** :
#
# https://sofifa.com/players?offset=360

# %% [markdown]
# # **8th Page :**
#
# https://sofifa.com/players?offset=420

# %% [markdown]
# # **9th Page :**
#
# https://sofifa.com/players?offset=480

# %% [markdown]
# # **10th Page :**
#
# https://sofifa.com/players?offset=540

# %%
headers = {"Accept-Language": "en-US,en;q=0.5"}

# %%
url01 = 'https://sofifa.com/players'

# %%
sumitresp01 = rq.get( url01 )

# %%
sumitresp01
# Out:
# <Response [200]>

# %%
sumitresp01.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en-US">\n<head><title>Players FIFA 22 Oct 20, 2021 SoFIFA</title>\n<meta charset="utf-8">\n<meta name="google-site-verification" content="VGaFvm9Qm-qhCd2LCDi8QKWXNPSrVE2SJ2iT8c3vI1g">\n<meta name="description" content="FIFA 22 player ratings on Oct 20, 2021">\n<meta name="author" content="Khachin Borjigin">\n<meta name="copyright" content="2009 - 2021 SoFIFA.com">\n<meta name="twitter:widgets:theme" content="light">\n<meta name="twitter:widgets:border-color" content="#e6e6e6">\n<link rel="shortcut icon" href="/launcher-icon.png">\n<link rel="apple-touch-icon" href="/launcher-icon.png">\n<link rel="preconnect" href="https://cdn.sofifa.com">\n<link rel="dns-prefetch" href="https://cdn.sofifa.com">\n<link rel="preconnect" href="https://pagead2.googlesyndication.com">\n<link rel="dns-prefetch" href="https://pagead2.googlesyndication.com">\n<script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-5614331754560452" crossorigin="anonymous"></script><link rel="alternate" hreflang="en" href="https://sofifa.com/players?hl=en-US">\n<link rel="alternate" hreflang="fr" href="https://sofifa.com/players?hl=fr-FR">\n<link rel="alternate" hreflang="de" href="https://sofifa.com/players?hl=de-DE">\n<link rel="alternate" hreflang="es" href="https://sofifa.com/players?hl=es-ES">\n<link rel="alternate" hreflang="it" href="https://sofifa.com/players?hl=it-IT">\n<link rel="alternate" hreflang="pt-BR" href="https://sofifa.com/players?hl=pt-BR">\n<link rel="alternate" hreflang="nl" href="https://sofifa.com/players?hl=nl-NL">\n<link rel="alternate" hreflang="ko" href="https://sofifa.com/players?hl=ko-KR">\n<link rel="alternate" hreflang="pl" href="https://sofifa.com/players?hl=pl-PL">\n<link rel="alternate" hreflang="zh-CN" href="https://sofifa.com/players?hl=zh-CN">\n<link rel="alternate" hreflang="ru" href="https://sofifa.com/players?hl=ru-RU">\n<link rel="alternate" hreflang="ja" href="https://sofifa.com/players?hl=ja-JP">\n<link rel="alternate" hreflang="sv" href="https://sofifa.com/players?hl=sv-SE">\n<link rel="alternate" hreflang="da" href="https://sofifa.com/players?hl=da-DK">\n<link rel="alternate" hreflang="pt-PT" href="https://sofifa.com/players?hl=pt-PT">\n<link rel="alternate" hreflang="nn" href="https://sofifa.com/players?hl=nn-NO">\n<link rel="alternate" hreflang="hu" href="https://sofifa.com/players?hl=hu-HU">\n<link rel="alternate" hreflang="cs" href="https://sofifa.com/players?hl=cs-CZ">\n<link rel="alternate" hreflang="fi" href="https://sofifa.com/players?hl=fi-FI">\n<link rel="alternate" hreflang="uk" href="https://sofifa.com/players?hl=uk-UA">\n<link rel="alternate" hreflang="tr" href="https://sofifa.com/players?hl=tr-TR">\n<link rel="alternate" hreflang="zh-HK" href="https://sofifa.com/players?hl=zh-HK">\n<link rel="alternate" hreflang="ar" href="https://sofifa.com/players?hl=ar-AA"><link rel="canonical" href="https://sofifa.com/players"><style type="text/css">html{font-family:sans-serif;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}article,aside,footer,header,nav,section{display:block}h1{font-size:2em;margin:.67em 0}figcaption,figure,main{display:block}hr{box-sizing:content-box;height:0;overflow:visible}a{background:transparent;-webkit-text-decoration-skip:objects}a:active,a:hover{outline-width:0}address{font-style:normal}b,strong{font-weight:inherit}b,strong{font-weight:bolder}code,kbd,pre,samp{font-family:inherit;font-size:1em}dfn{font-style:italic}small{font-size:80%;font-weight:400}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sub{bottom:-.25em}sup{top:-.5em}audio,video{display:inline-block}audio:not([controls]){display:none;height:0}img{border-style:none;max-width:100%}svg:not(:root){overflow:hidden}button,input,optgroup,select,textarea{font-family:inherit;font-size:inherit;line-height:inherit;margin:0}button,input{overflow:visible}button,select{text-transform:none}input::-webkit-inner-spin-button,input::-webkit-out ...

# %%
sumitsoup01 = BeautifulSoup( sumitresp01.content, 'lxml' )

# %%
sumitsoup01
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head><title>Players FIFA 22 Oct 20, 2021 SoFIFA</title>
# <meta charset="utf-8"/>
# <meta content="VGaFvm9Qm-qhCd2LCDi8QKWXNPSrVE2SJ2iT8c3vI1g" name="google-site-verification"/>
# <meta content="FIFA 22 player ratings on Oct 20, 2021" name="description"/>
# <meta content="Khachin Borjigin" name="author"/>
# <meta content="2009 - 2021 SoFIFA.com" name="copyright"/>
# <meta content="light" name="twitter:widgets:theme"/>
# <meta content="#e6e6e6" name="twitter:widgets:border-color"/>
# <link href="/launcher-icon.png" rel="shortcut icon"/>
# <link href="/launcher-icon.png" rel="apple-touch-icon"/>
# <link href="https://cdn.sofifa.com" rel="preconnect"/>
# <link href="https://cdn.sofifa.com" rel="dns-prefetch"/>
# <link href="https://pagead2.googlesyndication.com" rel="preconnect"/>
# <link href="https://pagead2.googlesyndication.com" rel="dns-prefetch"/>
# <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-5614331754560452"></script><link href="https://sofifa.com/players?hl=en-US" hreflang="en" rel="alternate"/>
# <link href="https://sofifa.com/players?hl=fr-FR" hreflang="fr" rel="alternate"/>
# <link href="https://sofifa.com/players?hl=de-DE" hreflang="de" rel="alternate"/>
# <link href="https://sofifa.com/players?hl=es-ES" hreflang="es" rel="alternate"/>
# <link href="https://sofifa.com/players?hl=it-IT" hreflang="it" rel="alternate"/>
# <link href="https://sofifa.com/players?hl=pt-BR" hreflang="pt-BR" rel="alternate"/>
# <link href="https://sofifa.com/players?hl=nl-NL" hreflang="nl" rel="alternate"/>
# <link href="https://sofifa.com/players?hl=ko-KR" hreflang="ko" rel="alternate"/>
# <link href="https://sofifa.com/players?hl=pl-PL" hreflang="pl" rel="alternate"/>
# <link href="https://sofifa.com/players?hl=zh-CN" hreflang="zh-CN" rel="alternate"/>
# <link href="https://sofifa.com/players?hl=ru-RU" hreflang="ru" rel="alternate"/>
# <link href="https://sofifa.com/players?hl=ja-JP" hreflang="ja" rel="alternate"/>
# <link href="https://sofifa.com/players?hl=sv-SE" hreflang="sv" rel="alternate"/>
# <link href="https://sofifa.com/players?hl=da-DK" hreflang="da" rel="alternate"/>
# <link href="https://sofifa.com/players?hl=pt-PT" hreflang="pt-PT" rel="alternate"/>
# <link href="https://sofifa.com/players?hl=nn-NO" hreflang="nn" rel="alternate"/>
# <link href="https://sofifa.com/players?hl=hu-HU" hreflang="hu" rel="alternate"/>
# <link href="https://sofifa.com/players?hl=cs-CZ" hreflang="cs" rel="alternate"/>
# <link href="https://sofifa.com/players?hl=fi-FI" hreflang="fi" rel="alternate"/>
# <link href="https://sofifa.com/players?hl=uk-UA" hreflang="uk" rel="alternate"/>
# <link href="https://sofifa.com/players?hl=tr-TR" hreflang="tr" rel="alternate"/>
# <link href="https://sofifa.com/players?hl=zh-HK" hreflang="zh-HK" rel="alternate"/>
# <link href="https://sofifa.com/players?hl=ar-AA" hreflang="ar" rel="alternate"/><link href="https://sofifa.com/players" rel="canonical"/><style type="text/css">html{font-family:sans-serif;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}article,aside,footer,header,nav,section{display:block}h1{font-size:2em;margin:.67em 0}figcaption,figure,main{display:block}hr{box-sizing:content-box;height:0;overflow:visible}a{background:transparent;-webkit-text-decoration-skip:objects}a:active,a:hover{outline-width:0}address{font-style:normal}b,strong{font-weight:inherit}b,strong{font-weight:bolder}code,kbd,pre,samp{font-family:inherit;font-size:1em}dfn{font-style:italic}small{font-size:80%;font-weight:400}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sub{bottom:-.25em}sup{top:-.5em}audio,video{display:inline-block}audio:not([controls]){display:none;height:0}img{border-style:none;max-width:100%}svg:not(:root){overflow:hidden}button,input,optgroup,select,textarea{font-family:inherit;font-size:inherit;line-height:inherit;margin:0}button,input{overflow:visible}button,select{text-transform:none}input::-webkit-inner-spin-button,input::-webkit-outer-spin-button{-webkit-appearance:none;margin:0}input[type=number]{-moz-appearance:textfield}[type=reset],[type=submit],button,html [type=button]{-webkit-appearance:button}[type=button]::-moz-focus-inner,[type=reset]::-moz-focus-inner,[type=submit]::-moz-focus-inner,button::-moz-focus-inner{border-style:none;padding:0}fieldset{border:0;margin:0;padding:0}legend{box-sizing:border-box;color:inherit;display:table;max-width:100%;padding:0;white-space:normal}progress{display:inline-block;vertical-align:baseline}textarea{overflow:auto}[type=checkbox],[type=radio]{box-sizing:border-box;padding:0}[type=number]::-webkit-inner-spin-button,[type=number]::-webkit-outer-spin-button{height:auto}[type=search]{-webkit-appearance:textfield;outline-offset:-2px}[type=search]::-webkit-search-cancel-button,[type=search]::-webkit-search-decoration{-webkit-appearance:none}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}details,menu{display:block}summary{display:list-item;outline:0}canvas{display:inline-block}template{display:none}html{-webkit-box-sizing:border-box;box-sizing:border-box}*,::after,::before{-webkit-box-sizing:inherit;box-sizing:inherit}p{margin-top:0;margin-bottom:.5rem}small{font-size:12px}strong{font-weight:500}::-moz-selection{color:#fff;background:#2b8a3e}::selection{color:#fff;background:#2b8a3e}.bp3-heading{color:#232222;font-weight:500;margin:0 0 .5rem;padding:0}.bp3-monospace-text{text-transform:none;font-family:monospace}.bp3-text-muted{color:#666}.bp3-text-disabled{color:#adb5bd}.bp3-text-overflow-ellipsis{overflow:hidden;text-overflow:ellipsis;white-space:nowrap;word-wrap:normal;display:block}a{text-decoration:none;color:#343a40}a:hover{cursor:pointer;text-decoration:underline;color:#212529}a .bp3-icon{color:inherit}.bp3-rtl{text-align:right}:focus{outline:0}.bp3-button,a.bp3-button{display:inline-block;background:#f1f3f5;color:#343a40;border:1px solid #dee2e6;cursor:pointer;padding:0 .5rem;text-align:center;font-size:inherit;min-width:1.8rem;min-height:1.8rem;line-height:1.7rem;position:relative;font-weight:500;text-transform:uppercase;white-space:nowrap;vertical-align:middle}.bp3-button .bp3-icon{vertical-align:middle}.bp3-button:hover{z-index:1;background:#e9ecef}.bp3-button::before,.bp3-button>*{margin-right:.35rem}.bp3-button:empty::before,.bp3-button>:last-child{margin-right:0}.bp3-button:empty{padding:0 !important}.bp3-button.bp3-fill{width:100%}.bp3-align-right .bp3-button,.bp3-button.bp3-align-right{text-align:right}.bp3-button:not([class*=bp3-intent-]).bp3-active,.bp3-button:not([class*=bp3-intent-]):active{color:#2b8a3e}.bp3-button:not([class*=bp3-intent-]).bp3-disabled,.bp3-button:not([class*=bp3-intent-]):disabled{outline:0;background:rgba(206,217,224,.5);color:rgba(92,112,128,.5)}.bp3-button:not([class*=bp3-intent-]).bp3-disabled.bp ...
# <script type="text/javascript">let CDN='https://cdn.sofifa.com',CDN_VERSION='20210431',HL='en-US',THEME='light',GENDER=0,IS_MOBILE=false,USER_ID=0,USER_AVATAR='https://cdn.sofifa.com/avatar?name=Guest',BLOCK='Block',UNBLOCK='Unblock',FOLLOW='Follow',UNFOLLOW='Unfollow',CHOOSE_FILE='Choose file...',UPLOADING='Uploading...',CHANGE='Change',UPDATED='Updated',DELETE_CONFIRM='Do you want to remove this item?',CANCEL='Cancel',OK='OK',CLOSE='Close',BLOCK_CONFIRM='Do you want to block this user?<br>You could change the settings under the \"My Relations\" section later.',HISTORY_VERSION='History Version',VERSION='22', ROSTER='220008',FONT=14,LOAD_MORE_COMMENTS='Load more comments',ADD_A_COMMENT='Add a comment',SORT_BY_NEWEST='Sort by Newest',SORT_BY_BEST='Sort by Best',MY_COMMENTS='My comments',POST='Post',JUST_NOW='just now',COLLAPSE_REPLIES='Collapse replies',COPY_URL='Copy URL',REPORT='Report',UPVOTE='Upvote',DOWNVOTE='Downvote',EDIT='Edit',REPLY='Reply',APPROVE='Approve',REMOVE='Remove',SHOW_FULL_COMMENT='Show full comment',LOAD_IMAGE='Load image',CANCEL_REPLY='Cancel reply',REPLY_TO_THIS_COMMENT='Reply to this comment',CANCEL_EDIT='Cancel edit',EDIT_THIS_COMMENT='Edit this comment',EXPAND_REPLIES='Expand replies',PLEASE_CHOOSE_A_REASON='Please choose a reason',RACISM='Racism',INSULT='Insult',SPAMMING='Spamming',PORN='Porn',PRIVATE_INFO='Private info',OTHER='Other',DESCRIPTION_OPTIONAL='Description (optional)',SAVING='Saving ...';</script>
# </head>
# <body class="is-preload " data-class="is-preload " id="list" lang="en-US">
# <header>
# <nav class="flex-centered bp3-navbar">
# <div class="center">
# <div class="bp3-navbar-group bp3-align-left reset">
# <div class="bp3-navbar-heading">
# <a href="/" rel="nofollow"><img alt="SoFIFA" src="https://cdn.sofifa.com/images/launcher-icon.png" style="height:1.5rem"/></a>
# </div>
# <a class="bp3-button bp3-minimal" href="/players">Players</a>
# <a class="bp3-button bp3-minimal" href="/teams">Teams</a>
# <a class="bp3-button bp3-minimal" href="/squads">Squads</a>
# <a class="bp3-button bp3-minimal" href="/shortlists">Shortlists</a>
# <a class="bp3-button bp3-minimal" href="/discussion/1" rel="nofollow">Discussions</a>
# </div>
# <div class="bp3-navbar-group bp3-align-right">
# <a class="bp3-button bp3-minimal need-sign-in" href="/signIn" rel="nofollow" role="button" tabindex="101">Sign in</a>
# <div class="dropdown dropdown-right">
# <a class="bp3-button bp3-minimal block dropdown-toggle" href="javascript:void(0);" rel="nofollow" role="button" tabindex="102" title="Settings"><span class="bp3-icon"><svg height="18" viewbox="0 0 24 24" width="18"><circle cx="12" cy="12" r="3"></circle><path d="M19.4 15a1.65 1.65 0 0 0 .33 1.82l.06.06a2 2 0 0 1 0 2.83 2 2 0 0 1-2.83 0l-.06-.06a1.65 1.65 0 0 0-1.82-.33 1.65 1.65 0 0 0-1 1.51V21a2 2 0 0 1-2 2 2 2 0 0 1-2-2v-.09A1.65 1.65 0 0 0 9 19.4a1.65 1.65 0 0 0-1.82.33l-.06.06a2 2 0 0 1-2.83 0 2 2 0 0 1 0-2.83l.06-.06a1.65 1.65 0 0 0 .33-1.82 1.65 1.65 0 0 0-1.51-1H3a2 2 0 0 1-2-2 2 2 0 0 1 2-2h.09A1.65 1.65 0 0 0 4.6 9a1.65 1.65 0 0 0-.33-1.82l-.06-.06a2 2 0 0 1 0-2.83 2 2 0 0 1 2.83 0l.06.06a1.65 1.65 0 0 0 1.82.33H9a1.65 1.65 0 0 0 1-1.51V3a2 2 0 0 1 2-2 2 2 0 0 1 2 2v.09a1.65 1.65 0 0 0 1 1.51 1.65 1.65 0 0 0 1.82-.33l.06-.06a2 2 0 0 1 2.83 0 2 2 0 0 1 0 2.83l-.06.06a1.65 1.65 0 0 0-.33 1.82V9a1.65 1.65 0 0 0 1.51 1H21a2 2 0 0 1 2 2 2 2 0 0 1-2 2h-.09a1.65 1.65 0 0 0-1.51 1z"></path></svg></span></a>
# <div class="bp3-menu">
# <div class="bp3-menu-header">Gender</div>
# <a class="bp3-menu-item bp3-active" href="/players?gender=0" rel="nofollow" role="button">Male</a>
# <a class="bp3-menu-item" href="/players?gender=1" rel="nofollow" role="button">Female</a>
# <div class="bp3-menu-header">Units</div>
# <a class="bp3-menu-item" href="/players?units=imperial" rel="nofollow" role="button">feet inches / lbs</a>
# <a class="bp3-menu-item bp3-active" href="/players?units=mks" rel="nofollow" role="button">cm / kg</a>
# <div class="bp3-menu-header">Currency</div>
# <a class="bp3-menu-item bp3-active" href="/players?currency=EUR" rel="nofollow" role="button">€ EUR</a>
# <a class="bp3-menu-item" href="/players?currency=USD" rel="nofollow" role="button">$ USD</a>
# <a class="bp3-menu-item" href="/players?currency=GBP" rel="nofollow" role="button">£ GBP</a>
# <div class="bp3-menu-header">Color schema</div>
# <a class="bp3-menu-item bp3-active" href="/players?engine=frostbite" rel="nofollow" role="button">Frostbite</a>
# <a class="bp3-menu-item" href="/players?engine=ignite" rel="nofollow" role="button">Ignite</a>
# <a class="bp3-menu-item" href="/players?engine=impact" rel="nofollow" role="button">Impact</a>
# <div class="bp3-menu-header">Potential</div>
# <a class="bp3-menu-item bp3-active" href="/players?potential=show" rel="nofollow" role="button">Show</a>
# <a class="bp3-menu-item" href="/players?potential=hide" rel="nofollow" role="button">Hide</a>
# </div>
# </div>
# <label class="bp3-button bp3-minimal block" for="theme">
# <input checked="" class="hide" id="theme" name="theme" type="checkbox" value="light"/>
# <span class="bp3-icon"><svg height="18" viewbox="0 0 24 24" width="18"><path d="M12 18q2.484 0 4.242-1.758t1.758-4.242-1.758-4.242-4.242-1.758q-1.219 0-2.484 0.563 1.547 0.703 2.508 2.18t0.961 3.258-0.961 3.258-2.508 2.18q1.266 0.563 2.484 0.563zM20.016 8.672l3.281 3.328-3.281 3.328v4.688h-4.688l-3.328 3.281-3.328-3.281h-4.688v-4.688l-3.281-3.328 3.281-3.328v-4.688h4.688l3.328-3.281 3.328 3.281h4.688v4.688z"></path></svg></span>
# </label>
# <a class="bp3-button bp3-minimal lang-toggle" href="javascript:void(0);" rel="nofollow" role="button" tabindex="104"><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/us.png" data-srcset="https://cdn.sofifa.com/flags/us@2x.png 2x, https://cdn.sofifa.com/flags/us@3x.png 3x" src="" title="United States"/> <span class="bp3-icon"><svg height="16" viewbox="0 0 24 24" width="16"><polyline points="6 9 12 15 18 9"></polyline></svg></span></a>
# </div>
# </div>
# </nav>
# <div class="flex-centered header hide" id="lang">
# <div class="center">
# <a class="bp3-button bp3-minimal lang" href="/players?hl=en-US" rel="nofollow" role="button"><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/us.png" data-srcset="https://cdn.sofifa.com/flags/us@2x.png 2x, https://cdn.sofifa.com/flags/us@3x.png 3x" src="" title="United States"/> English</a><a class="bp3-button bp3-minimal lang" href="/players?hl=de-DE" rel="nofollow" role="button"><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/de.png" data-srcset="https://cdn.sofifa.com/flags/de@2x.png 2x, https://cdn.sofifa.com/flags/de@3x.png 3x" src="" title="Germany"/> Deutsch</a><a class="bp3-button bp3-minimal lang" href="/players?hl=pt-BR" rel="nofollow" role="button"><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/br.png" data-srcset="https://cdn.sofifa.com/flags/br@2x.png 2x, https://cdn.sofifa.com/flags/br@3x.png 3x" src="" title="Brazil"/> Português Brasileiro</a><a class="bp3-button bp3-minimal lang" href="/players?hl=fr-FR" rel="nofollow" role="button"><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/fr.png" data-srcset="https://cdn.sofifa.com/flags/fr@2x.png 2x, https://cdn.sofifa.com/flags/fr@3x.png 3x" src="" title="France"/> Français</a><a class="bp3-button bp3-minimal lang" href="/players?hl=es-ES" rel="nofollow" role="button"><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/es.png" data-srcset="https://cdn.sofifa.com/flags/es@2x.png 2x, https://cdn.sofifa.com/flags/es@3x.png 3x" src="" title="Spain"/> Español</a><a class="bp3-button bp3-minimal lang" href="/players?hl=it-IT" rel="nofollow" role="button"><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/it.png" data-srcset="https://cdn.sofifa.com/flags/it@2x.png 2x, https://cdn.sofifa.com/flags/it@3x.png 3x" src="" title="Italy"/> Italiano</a><a class="bp3-button bp3-minimal lang" href="/players?hl=nl-NL" rel="nofollow" role="button"><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/nl.png" data-srcset="https://cdn.sofifa.com/flags/nl@2x.png 2x, https://cdn.sofifa.com/flags/nl@3x.png 3x" src="" title="Netherlands"/> Dutch</a><a class="bp3-button bp3-minimal lang" href="/players?hl=ja-JP" rel="nofollow" role="button"><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/jp.png" data-srcset="https://cdn.sofifa.com/flags/jp@2x.png 2x, https://cdn.sofifa.com/flags/jp@3x.png 3x" src="" title="Japan"/> 日本語</a><a class="bp3-button bp3-minimal lang" href="/players?hl=pl-PL" rel="nofollow" role="button"><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/pl.png" data-srcset="https://cdn.sofifa.com/flags/pl@2x.png 2x, https://cdn.sofifa.com/flags/pl@3x.png 3x" src="" title="Poland"/> Polski</a><a class="bp3-button bp3-minimal lang" href="/players?hl=tr-TR" rel="nofollow" role="button"><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/tr.png" data-srcset="https://cdn.sofifa.com/flags/tr@2x.png 2x, https://cdn.sofifa.com/flags/tr@3x.png 3x" src="" title="Turkey"/> Türkçe</a><a class="bp3-button bp3-minimal lang" href="/players?hl=zh-CN" rel="nofollow" role="button"><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/cn.png" data-srcset="https://cdn.sofifa.com/flags/cn@2x.png 2x, https://cdn.sofifa.com/flags/cn@3x.png 3x" src="" title="China PR"/> 中文(简体)</a><a class="bp3-button bp3-minimal lang" href="/players?hl=sv-SE" rel="nofollow" role="button"><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/se.png" data-srcset="https://cdn.sofifa.com/flags/se@2x.png 2x, https://cdn.sofifa.com/flags/se@3x.png 3x" src="" title="Sweden"/> Svenska</a><a class="bp3-button bp3-minimal lang" href="/players?hl=ru-RU" rel="nofollow" role="button"><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/ru.png" data-srcset="https://cdn.sofifa.com/flags/ru@2x.png 2x, https://cdn.sofifa.com/flags/ru@3x.png 3x" src="" title="Russia"/> Русский</a><a class="bp3-button bp3-minimal lang" href="/players?hl=pt-PT" rel="nofollow" role="button"><i ...
# </div>
# <div class="flex-centered header"><div class="center">
# <div class="top-banner" role="banner"><!-- PC top -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-5614331754560452" data-ad-format="horizontal" data-ad-slot="6054465379" data-full-width-responsive="true" style="display:block;width:728px;height:90px;"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <!--<div data-pw-desk="leaderboard_atf" style="width:728px;height:90px"></div>--></div>
# <h1 class="bp3-text-overflow-ellipsis">Players</h1>
# <h2>
# <div class="dropdown">
# <a class="bp3-button bp3-minimal text dropdown-toggle" href="javascript:void(0);" rel="nofollow" role="button" tabindex="200"><span class="bp3-button-text">FIFA 22</span><span class="bp3-icon bp3-icon-caret-down"><svg height="16" viewbox="0 0 24 24" width="16"><polyline points="6 9 12 15 18 9"></polyline></svg></span></a>
# <div class="bp3-menu">
# <a class="bp3-menu-item" href="/players?r=220008&amp;set=true">FIFA 22</a>
# <a class="bp3-menu-item" href="/players?r=210064&amp;set=true">FIFA 21</a>
# <a class="bp3-menu-item" href="/players?r=200061&amp;set=true">FIFA 20</a>
# <a class="bp3-menu-item" href="/players?r=190075&amp;set=true">FIFA 19</a>
# <a class="bp3-menu-item" href="/players?r=180084&amp;set=true">FIFA 18</a>
# <a class="bp3-menu-item" href="/players?r=170099&amp;set=true">FIFA 17</a>
# <a class="bp3-menu-item" href="/players?r=160058&amp;set=true">FIFA 16</a>
# <a class="bp3-menu-item" href="/players?r=150059&amp;set=true">FIFA 15</a>
# <a class="bp3-menu-item" href="/players?r=140052&amp;set=true">FIFA 14</a>
# <a class="bp3-menu-item" href="/players?r=130034&amp;set=true">FIFA 13</a>
# <a class="bp3-menu-item" href="/players?r=120002&amp;set=true">FIFA 12</a>
# <a class="bp3-menu-item" href="/players?r=110002&amp;set=true">FIFA 11</a>
# <a class="bp3-menu-item" href="/players?r=100002&amp;set=true">FIFA 10</a>
# <a class="bp3-menu-item" href="/players?r=090002&amp;set=true">FIFA 09</a>
# <a class="bp3-menu-item" href="/players?r=080002&amp;set=true">FIFA 08</a>
# <a class="bp3-menu-item" href="/players?r=070002&amp;set=true">FIFA 07</a>
# </div>
# </div>
# <div class="dropdown">
# <a class="bp3-button bp3-minimal text dropdown-toggle" href="javascript:void(0);" rel="nofollow" role="button" tabindex="200"><span class="bp3-button-text">Oct 20, 2021</span><span class="bp3-icon bp3-icon-caret-down"><svg height="16" viewbox="0 0 24 24" width="16"><polyline points="6 9 12 15 18 9"></polyline></svg></span></a>
# <div class="bp3-menu">
# <a class="bp3-menu-item" href="/players?r=220008&amp;set=true">Oct 20, 2021</a>
# <a class="bp3-menu-item" href="/players?r=220007&amp;set=true">Oct 14, 2021</a>
# <a class="bp3-menu-item" href="/players?r=220006&amp;set=true">Oct 1, 2021</a>
# <a class="bp3-menu-item" href="/players?r=220005&amp;set=true">Sep 28, 2021</a>
# <a class="bp3-menu-item" href="/players?r=220004&amp;set=true">Sep 27, 2021</a>
# <a class="bp3-menu-item" href="/players?r=220003&amp;set=true">Sep 25, 2021</a>
# <a class="bp3-menu-item" href="/players?r=220002&amp;set=true">Sep 23, 2021</a>
# <a class="bp3-menu-item" href="/players?r=220001&amp;set=true">Aug 16, 2021</a>
# </div>
# </div>
# </h2>
# </div></div>
# <div class="flex-centered sub-nav"><div class="center">
# <form action="/players" class="top-search bp3-input-group" method="get">
# <span class="bp3-icon bp3-icon-search"><svg height="16" viewbox="0 0 24 24" width="16"><circle cx="11" cy="11" r="8"></circle><line x1="21" x2="16.65" y1="21" y2="16.65"></line></svg></span>
# <input class="bp3-input player-suggest suggest" data-roster="220008" name="keyword" placeholder="Search Player ..." type="text"/>
# </form><div class="bp3-tabs">
# <div class="bp3-tab-list" role="tablist">
# <a aria-selected="true" class="bp3-tab" href="/players" role="tab">All</a>
# <a class="bp3-tab" href="/players?type=added" role="tab">Added</a>
# <a class="bp3-tab" href="/players?type=updated" role="tab">Updated</a>
# <a class="bp3-tab" href="/players?type=free" role="tab">Free</a>
# <a class="bp3-tab" href="/players?type=onLoan" role="tab">On Loan</a>
# <a class="bp3-tab" href="/players?type=removed" role="tab">Removed</a>
# <a class="bp3-tab" href="/players?type=customized" role="tab">Customized</a>
# <a class="bp3-tab need-sign-in" data-action="forward" href="/customize" role="tab">Create Player</a>
# <a class="bp3-tab" href="/calculator" role="tab">Calculator</a>
# </div>
# </div></div></div>
# </header>
# <div class="flex-centered">
# <div class="center">
# <div class="wrapper" id="adjust">
# <div class="grid grid-reverse">
# <div class="col">
# <div class="card"><table class="table table-hover persist-area">
# <thead>
# <tr class="persist-header">
# <th class="col-avatar"></th>
# <th class="col-name text-left">Name</th><th class="tooltip col col-ae" data-tooltip="Age"><a class="pjax bp3-text-overflow-ellipsis" href="/players?col=ae&amp;sort=asc" rel="nofollow"><span class="bp3-icon sorter"></span>Age</a></th><th class="tooltip col col-oa" data-tooltip="Overall Rating"><a class="pjax bp3-text-overflow-ellipsis" href="/players?col=oa&amp;sort=desc" rel="nofollow"><span class="bp3-icon sorter"></span>OVA</a></th><th class="tooltip col col-pt" data-tooltip="Potential"><a class="pjax bp3-text-overflow-ellipsis" href="/players?col=pt&amp;sort=desc" rel="nofollow"><span class="bp3-icon sorter"></span>POT</a></th><th class="tooltip col-name text-left" data-tooltip="Team &amp; Contract"><a class="pjax bp3-text-overflow-ellipsis" href="/players?col=tm&amp;sort=asc" rel="nofollow"><span class="bp3-icon sorter"></span>Team &amp; Contract</a></th>
# <th class="tooltip col col-vl" data-tooltip="Value"><a class="pjax bp3-text-overflow-ellipsis" href="/players?col=vl&amp;sort=asc" rel="nofollow"><span class="bp3-icon sorter"></span>Value</a></th><th class="tooltip col col-wg" data-tooltip="Wage"><a class="pjax bp3-text-overflow-ellipsis" href="/players?col=wg&amp;sort=asc" rel="nofollow"><span class="bp3-icon sorter"></span>Wage</a></th><th class="tooltip col col-tt" data-tooltip="Total Stats"><a class="pjax bp3-text-overflow-ellipsis" href="/players?col=tt&amp;sort=desc" rel="nofollow"><span class="bp3-icon sorter"></span>Total Stats</a></th></tr>
# </thead>
# <tbody class="list"><tr>
# <td class="col-avatar" data-balloon="Click here!" data-balloon-pos="up" data-balloon-visible=""><div class="popover popover-right">
# <figure class="avatar updated ">
# <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/241/637/22_60.png" data-srcset="https://cdn.sofifa.com/players/241/637/22_120.png 2x, https://cdn.sofifa.com/players/241/637/22_180.png 3x" data-type="player" id="241637" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure>
# <div class="popover-container">
# <div class="popover-arrow"></div>
# <div class="bp3-callout"><div class="block-quarter half-spacing pure-u-1-1"><a>FIFA 22 Oct 20, 2021</a></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-81">81</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-83">83</span></span> <abbr class="pure-u-7-24">Short Passing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-77">77</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-78">78</span></span> <abbr class="pure-u-7-24">Dribbling</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-82">82</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-83">83</span></span> <abbr class="pure-u-7-24">Long Passing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-79">79</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-80">80</span></span> <abbr class="pure-u-7-24">Ball Control</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-79">79</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-80">80</span></span> <abbr class="pure-u-7-24">Reactions</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-78">78</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-79">79</span></span> <abbr class="pure-u-7-24">Aggression</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-79">79</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-80">80</span></span> <abbr class="pure-u-7-24">Interceptions</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-79">79</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-81">81</span></span> <abbr class="pure-u-7-24">Standing Tackle</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-71">71</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-72">72</span></span> <abbr class="pure-u-7-24">Sliding Tackle</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-78">78</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-80">80</span></span> <abbr class="pure-u-7-24">Composure</abbr></div><div class="block-quarter pure-u-1-1"><abbr>and 12 more changes</abbr></div></div>
# </div></div></td>
# <td class="col-name">
# <a class="tooltip" data-tooltip="Aurélien Tchouaméni" href="/player/241637/aurelien-tchouameni/220008/"><div class="bp3-text-overflow-ellipsis">A. Tchouaméni</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/fr.png" data-srcset="https://cdn.sofifa.com/flags/fr@2x.png 2x, https://cdn.sofifa.com/flags/fr@3x.png 3x" src="" title="France"/> <a href="/players?pn=14" rel="nofollow"><span class="pos pos14">CM</span></a> <a href="/players?pn=10" rel="nofollow"><span class="pos pos10">CDM</span></a></td><td class="col col-ae" data-col="ae">21</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-80">80</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-87">87</span></td><td class="col-name">
# <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
# <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/69/30.png" data-srcset="https://cdn.sofifa.com/teams/69/60.png 2x, https://cdn.sofifa.com/teams/69/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
# </figure>
# <a href="/team/69/as-monaco/">AS Monaco</a><div class="sub">
# 2020 ~ 2024</div>
# </div>
# </td><td class="col col-vl" data-col="vl">€42.5M</td><td class="col col-wg" data-col="wg">€43K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">2104</span></td></tr><tr>
# <td class="col-avatar"><div class="popover popover-right">
# <figure class="avatar updated ">
# <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/235/212/22_60.png" data-srcset="https://cdn.sofifa.com/players/235/212/22_120.png 2x, https://cdn.sofifa.com/players/235/212/22_180.png 3x" data-type="player" id="235212" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure>
# <div class="popover-container">
# <div class="popover-arrow"></div>
# <div class="bp3-callout"><div class="block-quarter half-spacing pure-u-1-1"><a>FIFA 22 Oct 20, 2021</a></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-73">73</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-75">75</span></span> <abbr class="pure-u-7-24">Finishing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-60">60</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-74">74</span></span> <abbr class="pure-u-7-24">Volleys</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-95">95</span> <span class="bp3-icon bp3-icon-arrow-bottom-right">↘</span> <span class="bp3-tag p p-93">93</span></span> <abbr class="pure-u-7-24">Acceleration</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-86">86</span> <span class="bp3-icon bp3-icon-arrow-bottom-right">↘</span> <span class="bp3-tag p p-84">84</span></span> <abbr class="pure-u-7-24">Agility</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-91">91</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-93">93</span></span> <abbr class="pure-u-7-24">Stamina</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-73">73</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-74">74</span></span> <abbr class="pure-u-7-24">Strength</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-78">78</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-79">79</span></span> <abbr class="pure-u-7-24">Positioning</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-75">75</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-78">78</span></span> <abbr class="pure-u-7-24">Vision</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-80">80</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-83">83</span></span> <abbr class="pure-u-7-24">Composure</abbr></div><div class="block-quarter pure-u-1-1"><abbr><del>Dives Into Tackles (AI)</del></abbr></div><div class="block-quarter pure-u-1-1"><abbr>and 11 more changes</abbr></div></div>
# </div></div></td>
# <td class="col-name">
# <a class="tooltip" data-tooltip="Achraf Hakimi" href="/player/235212/achraf-hakimi/220008/"><div class="bp3-text-overflow-ellipsis">A. Hakimi</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/ma.png" data-srcset="https://cdn.sofifa.com/flags/ma@2x.png 2x, https://cdn.sofifa.com/flags/ma@3x.png 3x" src="" title="Morocco"/> <a href="/players?pn=3" rel="nofollow"><span class="pos pos3">RB</span></a> <a href="/players?pn=2" rel="nofollow"><span class="pos pos2">RWB</span></a></td><td class="col col-ae" data-col="ae">22</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-85">85</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-89">89</span></td><td class="col-name">
# <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
# <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/73/30.png" data-srcset="https://cdn.sofifa.com/teams/73/60.png 2x, https://cdn.sofifa.com/teams/73/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
# </figure>
# <a href="/team/73/paris-saint-germain/">Paris Saint-Germain</a><div class="sub">
# 2021 ~ 2026</div>
# </div>
# </td><td class="col col-vl" data-col="vl">€73M</td><td class="col col-wg" data-col="wg">€100K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">2207</span></td></tr><tr>
# <td class="col-avatar"><div class="popover popover-right">
# <figure class="avatar updated ">
# <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/256/287/22_60.png" data-srcset="https://cdn.sofifa.com/players/256/287/22_120.png 2x, https://cdn.sofifa.com/players/256/287/22_180.png 3x" data-type="player" id="256287" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure>
# <div class="popover-container">
# <div class="popover-arrow"></div>
# <div class="bp3-callout"><div class="block-quarter half-spacing pure-u-1-1"><a>FIFA 22 Oct 20, 2021</a></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-72">72</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-73">73</span></span> <abbr class="pure-u-7-24">Finishing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-68">68</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-72">72</span></span> <abbr class="pure-u-7-24">Short Passing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-75">75</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-78">78</span></span> <abbr class="pure-u-7-24">Dribbling</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-61">61</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-63">63</span></span> <abbr class="pure-u-7-24">Curve</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-66">66</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-70">70</span></span> <abbr class="pure-u-7-24">Long Passing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-74">74</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-77">77</span></span> <abbr class="pure-u-7-24">Ball Control</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-89">89</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-90">90</span></span> <abbr class="pure-u-7-24">Acceleration</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-77">77</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-79">79</span></span> <abbr class="pure-u-7-24">Sprint Speed</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-89">89</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-90">90</span></span> <abbr class="pure-u-7-24">Balance</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-73">73</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-76">76</span></span> <abbr class="pure-u-7-24">Shot Power</abbr></div><div class="block-quarter pure-u-1-1"><abbr>and 20 more changes</abbr></div></div>
# </div></div></td>
# <td class="col-name">
# <a class="tooltip" data-tooltip="Facundo Farías" href="/player/256287/facundo-farias/220008/"><div class="bp3-text-overflow-ellipsis">F. Farías</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/ar.png" data-srcset="https://cdn.sofifa.com/flags/ar@2x.png 2x, https://cdn.sofifa.com/flags/ar@3x.png 3x" src="" title="Argentina"/> <a href="/players?pn=25" rel="nofollow"><span class="pos pos25">ST</span></a> <a href="/players?pn=21" rel="nofollow"><span class="pos pos21">CF</span></a></td><td class="col col-ae" data-col="ae">18</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-73">73</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-85">85</span></td><td class="col-name">
# <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
# <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/110406/30.png" data-srcset="https://cdn.sofifa.com/teams/110406/60.png 2x, https://cdn.sofifa.com/teams/110406/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
# </figure>
# <a href="/team/110406/club-atletico-colon/">Club Atlético Colón</a><div class="sub">
# 2020 ~ 2023</div>
# </div>
# </td><td class="col col-vl" data-col="vl">€7M</td><td class="col col-wg" data-col="wg">€5K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">1888</span></td></tr><tr>
# <td class="col-avatar"><div class="popover popover-right">
# <figure class="avatar updated ">
# <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/213/661/22_60.png" data-srcset="https://cdn.sofifa.com/players/213/661/22_120.png 2x, https://cdn.sofifa.com/players/213/661/22_180.png 3x" data-type="player" id="213661" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure>
# <div class="popover-container">
# <div class="popover-arrow"></div>
# <div class="bp3-callout"><div class="block-quarter half-spacing pure-u-1-1"><a>FIFA 22 Oct 20, 2021</a></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-66">66</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-67">67</span></span> <abbr class="pure-u-7-24">Dribbling</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-71">71</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-72">72</span></span> <abbr class="pure-u-7-24">Long Passing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-73">73</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-74">74</span></span> <abbr class="pure-u-7-24">Ball Control</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-69">69</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-75">75</span></span> <abbr class="pure-u-7-24">Sprint Speed</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-79">79</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-82">82</span></span> <abbr class="pure-u-7-24">Reactions</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-75">75</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-78">78</span></span> <abbr class="pure-u-7-24">Jumping</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-73">73</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-74">74</span></span> <abbr class="pure-u-7-24">Strength</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-73">73</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-74">74</span></span> <abbr class="pure-u-7-24">Aggression</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-82">82</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-84">84</span></span> <abbr class="pure-u-7-24">Interceptions</abbr></div><div class="block-quarter pure-g"><abbr class="pure-u-7-24">Height</abbr> <span class="pure-u-17-24">187cm <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> 188cm</span></div><div class="block-quarter pure-u-1-1"><abbr>and 13 more changes</abbr></div></div>
# </div></div></td>
# <td class="col-name">
# <a class="tooltip" data-tooltip="Andreas Christensen" href="/player/213661/andreas-christensen/220008/"><div class="bp3-text-overflow-ellipsis">A. Christensen</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/dk.png" data-srcset="https://cdn.sofifa.com/flags/dk@2x.png 2x, https://cdn.sofifa.com/flags/dk@3x.png 3x" src="" title="Denmark"/> <a href="/players?pn=5" rel="nofollow"><span class="pos pos5">CB</span></a></td><td class="col col-ae" data-col="ae">25</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-81">81</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-85">85</span></td><td class="col-name">
# <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
# <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/5/30.png" data-srcset="https://cdn.sofifa.com/teams/5/60.png 2x, https://cdn.sofifa.com/teams/5/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
# </figure>
# <a href="/team/5/chelsea/">Chelsea</a><div class="sub">
# 2013 ~ 2022</div>
# </div>
# </td><td class="col col-vl" data-col="vl">€32M</td><td class="col col-wg" data-col="wg">€100K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">1753</span></td></tr><tr>
# <td class="col-avatar"><div class="popover popover-right">
# <figure class="avatar updated ">
# <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/224/081/22_60.png" data-srcset="https://cdn.sofifa.com/players/224/081/22_120.png 2x, https://cdn.sofifa.com/players/224/081/22_180.png 3x" data-type="player" id="224081" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure>
# <div class="popover-container">
# <div class="popover-arrow"></div>
# <div class="bp3-callout"><div class="block-quarter half-spacing pure-u-1-1"><a>FIFA 22 Oct 20, 2021</a></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-65">65</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-66">66</span></span> <abbr class="pure-u-7-24">Heading Accuracy</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-80">80</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-82">82</span></span> <abbr class="pure-u-7-24">Short Passing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-79">79</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-80">80</span></span> <abbr class="pure-u-7-24">Ball Control</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-66">66</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-67">67</span></span> <abbr class="pure-u-7-24">Sprint Speed</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-85">85</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-86">86</span></span> <abbr class="pure-u-7-24">Stamina</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-67">67</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-68">68</span></span> <abbr class="pure-u-7-24">Long Shots</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-77">77</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-78">78</span></span> <abbr class="pure-u-7-24">Interceptions</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-74">74</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-75">75</span></span> <abbr class="pure-u-7-24">Vision</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-79">79</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-80">80</span></span> <abbr class="pure-u-7-24">Marking</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-77">77</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-78">78</span></span> <abbr class="pure-u-7-24">Sliding Tackle</abbr></div><div class="block-quarter pure-u-1-1"><abbr>and 11 more changes</abbr></div></div>
# </div></div></td>
# <td class="col-name">
# <a class="tooltip" data-tooltip="Kalvin Phillips" href="/player/224081/kalvin-phillips/220008/"><div class="bp3-text-overflow-ellipsis">K. Phillips</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/gb-eng.png" data-srcset="https://cdn.sofifa.com/flags/gb-eng@2x.png 2x, https://cdn.sofifa.com/flags/gb-eng@3x.png 3x" src="" title="England"/> <a href="/players?pn=10" rel="nofollow"><span class="pos pos10">CDM</span></a> <a href="/players?pn=14" rel="nofollow"><span class="pos pos14">CM</span></a> <a href="/players?pn=5" rel="nofollow"><span class="pos pos5">CB</span></a></td><td class="col col-ae" data-col="ae">25</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-81">81</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-85">85</span></td><td class="col-name">
# <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
# <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/8/30.png" data-srcset="https://cdn.sofifa.com/teams/8/60.png 2x, https://cdn.sofifa.com/teams/8/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
# </figure>
# <a href="/team/8/leeds-united/">Leeds United</a><div class="sub">
# 2014 ~ 2024</div>
# </div>
# </td><td class="col col-vl" data-col="vl">€32.5M</td><td class="col col-wg" data-col="wg">€82K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">2101</span></td></tr><tr>
# <td class="col-avatar"><div class="popover popover-right">
# <figure class="avatar updated ">
# <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/248/808/22_60.png" data-srcset="https://cdn.sofifa.com/players/248/808/22_120.png 2x, https://cdn.sofifa.com/players/248/808/22_180.png 3x" data-type="player" id="248808" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure>
# <div class="popover-container">
# <div class="popover-arrow"></div>
# ...
# LOAD_IMAGE+"</button></a></p><p>");g=matchAll(k,/(?:youtube\.com\/\S*(?:(?:\/e(?:mbed))?\/|watch\/?\?(?:\S*?&?v=))|youtu\.be\/)([a-zA-Z0-9_-]{6,11})/g);for(e in g){var m=g[e][0].replace("youtube.com/embed/","").replace("youtube.com/watch?v=","").replace("youtu.be/","");k=k.replace(g[e][0],g[e][0]+'</p><p><a href="https://youtube.com/watch?v='+m+'" target="_blank" class="youtube" rel="noreferrer" style="background-image: url(https://i.ytimg.com/vi/'+m+'/hqdefault.jpg);" data-lity><img alt="" src="'+
# CDN+'/img/play.png" data-srcset="'+CDN+"/img/play@2x.png 2x, "+CDN+'/img/play@3x.png 3x" class="play" width="68" height="48">https://youtube.com/watch?v='+m+"</a></p><p>")}g=matchAll(k,/(https?:\/\/)?www\.facebook\.com\/(?:(videos|posts)\.php\?v=\d+|.*?\/(videos|posts)\/\d+\/?)/gi);for(e in g)k=k.replace(g[e][0],g[e][0]+'</p><div id="'+a+"-facebook-"+e+'"></div><p>'),h[a+"-facebook-"+e]=g[e][0];g=matchAll(k,/((https?:\/\/)(www\.)?instagram.com\/p\/[a-zA-Z0-9_\-=]+)(\/\?[a-zA-Z0-9_\-=]+)?/gi);for(e in g)k=
# k.replace(g[e][0],g[e][0]+'</p><div id="'+a+"-instagram-"+e+'"></div><p>'),h[a+"-instagram-"+e]=g[e][0];g=matchAll(k,/https:\/\/twitter\.com\/\w+\/\w+\/\d+/gi);for(e in g)k=k.replace(g[e][0],g[e][0]+'</p><div id="'+a+"-twitter-"+e+'" class="embed-twitter"></div><p>'),h[a+"-twitter-"+e]=g[e][0];k=k.replace(/(https?:\/\/sofifa\.com(\/[A-Za-z0-9\-\._~:\/\?#\[\]@!$&'\(\)\*\+,;=]*)?)/g,'<a href="$1">$1</a>');1E3<k.length||10<(k.match(/<p>/g)||[]).length?$("#"+a).html('<input type="checkbox" id="comment-check-'+
# a+'" checked="checked" class="tabbed hide"><div class="tabbed-text">'+k.replace(/<p>\n<\/p>/g,"").replace(/<p><\/p>/g,"")+'</div><div class="content-more"><div class="gradient"></div><label for="comment-check-'+a+'" class="bp3-button bp3-fill fill pure-button text-left"><svg viewBox="0 0 24 24" width="16" height="16"><polyline points="6 9 12 15 18 9"></polyline></svg> '+SHOW_FULL_COMMENT+"</label></div>"):$("#"+a).html(k.replace(/<p>\n<\/p>/g,"").replace(/<p><\/p>/g,""));for(e in h)embedo.load(document.getElementById(e),
# h[e],{tagName:"img",height:480})}}
# $(document).ready(function(){function a(){var a=$('select[name="comment-order"]').val(),h=a.indexOf("=points"),g=a.indexOf("=desc");$.ajax({type:"GET",url:"/api/v1.1/comments?path="+IDENTIFIER+"&"+a+"&rootId="+ROOT_ID+"&_="+(new Date).getTime(),success:function(a){if("undefined"!=typeof a.error)$.alert(a.error.message);else if(a.length){$("#bp3-spinner").remove();var b=-1E5,c,e=0;for(c in a){var d=a[c];d.parentId?($("#reply-"+d.parentId).append(renderComment(d)),renderCommentHtml("text-"+d.postId,
# d.content),$(".timeago").timeago()):(b=0<h?0<g?parseFloat(b)>parseFloat(d.points)||-1E5===b?d.points:b:parseFloat(b)<parseFloat(d.points)?d.points:b:0<g?parseFloat(b)>parseFloat(d.postId)||-1E5===b?d.postId:b:parseFloat(b)<parseFloat(d.postId)?d.postId:b,$("#comments").append('<div class="comments" data-id="'+d.postId+'" data-points="'+d.points+'">'+renderComment(d)+"</div>"),renderCommentHtml("text-"+d.postId,d.content),$(".timeago").timeago(),e++)}10===e&&$("#comments").append('<div class="more-wrapper"><button class="bp3-button bp3-intent-primary load-more full-width pure-button" data-offset="'+
# b+'">'+LOAD_MORE_COMMENTS+"</button></div>")}else $("#bp3-spinner").remove()}})}$.ajaxSettings=$.extend($.ajaxSettings,{cache:!0,accepts:"application/json",error:function(a,h,g){switch(a.status){case 401:$.dialog($("#sign-in-form").html());break;case 502:$.alert("Error: Bad Gateway")}}});$(document).on("change, keyup","textarea",function(){var a=($(this).val().match(/\n/g)||[]).length;$(this).css({height:1.5*((3<a?a:3)+2)+"em"})});"undefined"!=typeof IDENTIFIER&&a();if("undefined"!=typeof IDENTIFIER&&
# "undefined"!=typeof LIVE_COMMENT){var k=io("https://socket.sofifa.com");k.on("connect",function(){k.emit("login",USER_ID+"@"+IDENTIFIER)});k.on("newPost",function(a){var e=JSON.parse(a);setTimeout(function(){if(1>$("#comment-"+e.postId).length){e.parentId?$("#reply-"+e.parentId).length&&($("#reply-"+e.parentId).append(renderComment(e,$("#new-post #comment-"+e.parentId).length?"hidden":"pre-blur")),renderCommentHtml("text-"+e.postId,e.content),$(".timeago").timeago()):(1>$("#new-post").length&&$("#comments").prepend('<div id="new-post"><button class="bp3-button bp3-intent-primary full-width show-comment pure-button">Show 1 new comment</button></div>'),
# $("#new-post").prepend('<div class="comments">'+renderComment(e,"hidden")+"</div>"),renderCommentHtml("text-"+e.postId,e.content),$(".timeago").timeago());var a=$("#new-post .comment").length;1<a&&$(".show-comment").text("Show "+a+" new comments")}},1E3,e)})}$(document).on("change",'select[name="comment-order"]',function(){$("#comments > *").remove();$("#comments").append('<div id="bp3-spinner" class="bp3-spinner"><div class="bp3-spinner-animation"><svg width="50" height="50" stroke-width="8.00" viewBox="1.00 1.00 98.00 98.00"><path class="bp3-spinner-track" d="M 50,50 m 0,-45 a 45,45 0 1 1 0,90 a 45,45 0 1 1 0,-90"></path><path class="bp3-spinner-head" d="M 50,50 m 0,-45 a 45,45 0 1 1 0,90 a 45,45 0 1 1 0,-90" pathLength="280" stroke-dasharray="280 280" stroke-dashoffset="210"></path></svg></div></div>');
# a()});$(window).scroll(function(){$(".pre-blur").whenInViewport(function(a){a.addClass("blur")})});$(document).on("click",".show-comment",function(){$("#new-post .hidden").addClass("blur").removeClass("hidden");$(this).unwrap().remove()});$(document).on("click",".load-more",function(){var a=$('select[name="comment-order"]').val(),h=a.indexOf("=points"),g=a.indexOf("=desc"),k=$(this).data("offset"),b=$(this).parent();$(this).replaceWith('<div id="bp3-spinner" class="bp3-spinner"><div class="bp3-spinner-animation"><svg width="50" height="50" stroke-width="8.00" viewBox="1.00 1.00 98.00 98.00"><path class="bp3-spinner-track" d="M 50,50 m 0,-45 a 45,45 0 1 1 0,90 a 45,45 0 1 1 0,-90"></path><path class="bp3-spinner-head" d="M 50,50 m 0,-45 a 45,45 0 1 1 0,90 a 45,45 0 1 1 0,-90" pathLength="280" stroke-dasharray="280 280" stroke-dashoffset="210"></path></svg></div></div>');
# $.ajax({type:"GET",url:"/api/v1.1/comments?path="+IDENTIFIER+"&"+a+"&offset="+k,success:function(a){if("undefined"!=typeof a.error)$.alert(a.error.message);else if(a.length){$("#bp3-spinner").remove();k=-1E5;var c,d=0;for(c in a){var e=a[c];e.parentId?($("#reply-"+e.parentId).append(renderComment(e)),renderCommentHtml("text-"+e.postId,e.content),$(".timeago").timeago()):(k=0<h?0<g?parseFloat(k)>parseFloat(e.points)||-1E5===k?e.points:k:parseFloat(k)<parseFloat(e.points)?e.points:k:0<g?parseFloat(k)>
# parseFloat(e.postId)||-1E5===k?e.postId:k:parseFloat(k)<parseFloat(e.postId)?e.postId:k,b.append('<div class="comments" data-id="'+e.postId+'" data-points="'+e.points+'">'+renderComment(e)+"</div>"),renderCommentHtml("text-"+e.postId,e.content),$(".timeago").timeago(),d++)}10===d&&b.append('<div class="more-wrapper"><button class="bp3-button bp3-intent-primary load-more full-width pure-button" data-offset="'+k+'">'+LOAD_MORE_COMMENTS+"</button></div>")}}})});$(document).on("click",".text > .attachment",
# function(){if(1>USER_ID)$.dialog($("#sign-in-form").html());else{var a=$(this).attr("id");new Uploader({id:a,action:"/api/v1.1/comment/attachment",multiple:!1,loading:!0,maxSize:5242880,name:"attachment",classNames:[],headers:{},data:{},accept:"image/*",onStart:function(){},onProgress:function(){},onSuccess:function(e){if("undefined"!=typeof e.url){var g=$("#"+a).parent().parent().find("textarea"),h=g.val();g.val((h.length?h+"\r\n":"")+e.url)}else $.alert(e.error.message)},onError:function(a){}});
# $(this).trigger("click")}});$(document).on("click",".post-comment button.post",function(){if(1>USER_ID)$.dialog($("#sign-in-form").html());else{var a=$(this);a.prop("disabled",!0);var h=$(this).parent().find("textarea"),g=h.val();$.ajax({type:"POST",url:"/api/v1.1/comment",data:{path:IDENTIFIER,parentId:0,content:g},success:function(e){"undefined"!=typeof e.error?$.alert(e.error.message):($("#comments").prepend('<div class="comments">'+renderComment(e)+"</div>"),renderCommentHtml("text-"+e.postId,
# e.content),$(".timeago").timeago(),h.val(""),a.prop("disabled",!1))}})}});$(document).on("click",".reply-comment button.post",function(){if(1>USER_ID)$.dialog($("#sign-in-form").html());else{$(this).prop("disabled",!0);var a=$(this).parent().find("textarea").val(),h=$(this).data("id");$.ajax({type:"POST",url:"/api/v1.1/comment",data:{path:IDENTIFIER,parentId:h,content:a},success:function(a){"undefined"!=typeof a.error?$.alert(a.error.message):($("#reply-"+a.parentId+" .reply-comment").replaceWith(renderComment(a)),
# renderCommentHtml("text-"+a.postId,a.content),$(".timeago").timeago())}})}});$(document).on("click",".edit-comment button.post",function(){if(1>USER_ID)$.dialog($("#sign-in-form").html());else{$(this).prop("disabled",!0);var a=$(this).parent().find("textarea").val(),h=$(this).data("id");$.ajax({type:"POST",url:"/api/v1.1/comment/"+h,data:{content:a},success:function(a){"undefined"!=typeof a.error?$.alert(a.error.message):($("#edit-"+h).replaceWith(renderComment(a)),renderCommentHtml("text-"+a.postId,
# a.content),$(".timeago").timeago())}})}});$(document).on("click",".actions .reply",function(){if(1>USER_ID)$.dialog($("#sign-in-form").html());else{var a=$(this).data("id"),h=$("#reply-"+a+" > .reply-comment");h.length?h.remove():(h='<div class="comment reply-comment"><div class="avatar"><img alt="avatar" src="'+USER_AVATAR+'"></div><div class="content"><div class="text"><textarea name="content" class="bp3-input"></textarea><button name="post" class="bp3-button bp3-intent-primary post pure-button pure-button-primary" data-id="'+
# a+'"><svg viewBox="0 0 24 24" width="16" height="16"><line x1="22" y1="2" x2="11" y2="13"></line><polygon points="22 2 15 22 11 13 2 9 22 2"></polygon></svg> '+POST+'</button><span id="reply-attachment-'+a+'" class="attachment"><svg viewBox="0 0 24 24" width="16" height="16"><path d="M21.44 11.05l-9.19 9.19a6 6 0 0 1-8.49-8.49l9.19-9.19a4 4 0 0 1 5.66 5.66l-9.2 9.19a2 2 0 0 1-2.83-2.83l8.49-8.48"></path></svg> '+CHOOSE_FILE+' &nbsp; <span class="spin"></span></span></div></div></div>',$("#reply-"+
# a).prepend(h))}});$(document).on("click",".actions .edit",function(){var a=$(this).data("id"),h='<div id="edit-'+a+'" class="comment edit-comment"><div class="avatar"><img alt="avatar" src="'+USER_AVATAR+'"></div><div class="content"><div class="text"><textarea name="content" class="bp3-input">'+decodeURIComponent($(this).data("content"))+'</textarea><button name="post" class="bp3-button bp3-intent-primary post pure-button pure-button-primary" data-id="'+a+'"><svg viewBox="0 0 24 24" width="16" height="16"><line x1="22" y1="2" x2="11" y2="13"></line><polygon points="22 2 15 22 11 13 2 9 22 2"></polygon></svg> '+
# POST+'</button><span id="edit-attachment-'+a+'" class="attachment"><svg viewBox="0 0 24 24" width="16" height="16"><path d="M21.44 11.05l-9.19 9.19a6 6 0 0 1-8.49-8.49l9.19-9.19a4 4 0 0 1 5.66 5.66l-9.2 9.19a2 2 0 0 1-2.83-2.83l8.49-8.48"></path></svg> '+CHOOSE_FILE+' &nbsp; <span class="spin"></span></span></div></div></div>';$("#comment-"+a).replaceWith(h)});$(document).on("click",".actions .delete",function(){if(1>USER_ID)$.dialog($("#sign-in-form").html());else{var a=$(this).data("id");$.confirm(DELETE_CONFIRM,
# function(e){e&&($("#dialog").remove(),$.ajax({type:"POST",url:"/api/v1.1/comment/"+a+"/delete",success:function(e){"undefined"!=typeof e.error?$.alert(e.error.message):$("#comment-"+a).remove()}}))})}});$(document).on("click",".actions .upvote",function(){if(1>USER_ID)$.dialog($("#sign-in-form").html());else{var a=$(this).data("id");$.ajax({type:"POST",url:"/api/v1.1/comment/"+a+"/vote",data:{direction:1},success:function(e){if("undefined"!=typeof e.error)$.alert(e.error.message);else{var g=$("#upvote-"+
# a);switch(e){case "Upvoted":g.text(1*g.text().replace(/[^\d-.]/g,"")+1);g.parent().addClass("upvoted");break;case "Reset":g.text(1*g.text().replace(/[^\d-.]/g,"")-1);g.parent().removeClass("upvoted");break;case "Reupvoted":g.text(1*g.text().replace(/[^\d-.]/g,"")+1),g.parent().addClass("upvoted"),g=$("#downvote-"+a),g.text(1*g.text().replace(/[^\d-.]/g,"")-1),g.parent().removeClass("downvoted")}}}})}});$(document).on("click",".actions .downvote",function(){if(1>USER_ID)$.dialog($("#sign-in-form").html());
# else{var a=$(this).data("id");$.ajax({type:"POST",url:"/api/v1.1/comment/"+a+"/vote",data:{direction:-1},success:function(e){if("undefined"!=typeof e.error)$.alert(e.error.message);else{var g=$("#downvote-"+a);switch(e){case "Downvoted":g.text(1*g.text().replace(/[^\d-.]/g,"")+1);g.parent().addClass("downvoted");break;case "Reset":g.text(1*g.text().replace(/[^\d-.]/g,"")-1);g.parent().removeClass("downvoted");break;case "Redownvoted":g.text(1*g.text().replace(/[^\d-.]/g,"")+1),g.parent().addClass("downvoted"),
# g=$("#upvote-"+a),g.text(1*g.text().replace(/[^\d-.]/g,"")-1),g.parent().removeClass("upvoted")}}}})}});$(document).on("click",".actions .report",function(){if(1>USER_ID)$.dialog($("#sign-in-form").html());else{var a=$(this).data("id");$("#send-report").attr("data-id",a);$.dialog($("#report-form").html())}});$(document).on("click","#send-report",function(){if(1>USER_ID)$.dialog($("#sign-in-form").html());else{var a=$(this).data("id");$.ajax({type:"POST",url:"/api/v1.1/comment/"+a+"/report",data:{reason:$("#report-reason").val(),
# description:$("#report-description").val()},success:function(e){"undefined"!=typeof e.error?$.alert(e.error.message):($("#dialog").remove(),$("#comment-"+a+" > .content .report").addClass("reported"))}})}});$(document).on("click",".actions .block-user",function(){if(1>USER_ID)$.dialog($("#sign-in-form").html());else{var a=$(this).data("id");$("#block-user").attr("data-id",a);$.dialog($("#block-form").html())}});$(document).on("click","#block-user",function(){if(1>USER_ID)$.dialog($("#sign-in-form").html());
# else{var a=$(this).data("id");$.ajax({type:"POST",url:"/api/v1.1/user/"+a+"/block",data:{hideMyPost:$('#dialog input[name="hide-my"]').prop("checked")?1:0,hideHisPost:$('#dialog input[name="hide-his"]').prop("checked")?1:0},success:function(e){if("undefined"!=typeof e.error)$.alert(e.error.message);else switch($("#dialog").remove(),e){case "HideHisPost":case "Both":$(".comment.user-"+a).remove()}}})}});$(document).on("click",".comment-option-collapse",function(){var a=$(this).data("id");$("#text-"+
# a).toggleClass("hide");$("#actions-"+a).toggleClass("hide");$("#reply-"+a).toggleClass("hide");$(this).html('<svg viewBox="0 0 24 24" width="16" height="16"><line x1="12" y1="5" x2="12" y2="19"></line><line x1="5" y1="12" x2="19" y2="12"></line></svg>'==$(this).html()?'<svg viewBox="0 0 24 24" width="16" height="16"><line x1="5" y1="12" x2="19" y2="12"></line></svg>':'<svg viewBox="0 0 24 24" width="16" height="16"><line x1="12" y1="5" x2="12" y2="19"></line><line x1="5" y1="12" x2="19" y2="12"></line></svg>')});
# $(document).on("click",".load-image",function(a){a.preventDefault();a=$(this).attr("href");$(this).html('<img src="'+a+'">')})});
# </script><script>!function(e,a,t,n,g,c){e.GoogleAnalyticsObject=n,e.ga=e.ga||function(){(e.ga.q=e.ga.q||[]).push(arguments)},e.ga.l=+new Date,g=a.createElement(t),c=a.getElementsByTagName(t)[0],g.async=1,g.src="https://www.google-analytics.com/analytics.js",c.parentNode.insertBefore(g,c)}(window,document,"script","ga"),ga("create","UA-27924384-1","auto"),ga("send","pageview");</script>
# </body>
# </html>

# %%
sumit_data01 = sumitsoup01.findAll('tbody', attrs = {'class': 'list'})

# %%
sumit_data01
# Out:
# [<tbody class="list"><tr>
#  <td class="col-avatar" data-balloon="Click here!" data-balloon-pos="up" data-balloon-visible=""><div class="popover popover-right">
#  <figure class="avatar updated ">
#  <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/241/637/22_60.png" data-srcset="https://cdn.sofifa.com/players/241/637/22_120.png 2x, https://cdn.sofifa.com/players/241/637/22_180.png 3x" data-type="player" id="241637" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure>
#  <div class="popover-container">
#  <div class="popover-arrow"></div>
#  <div class="bp3-callout"><div class="block-quarter half-spacing pure-u-1-1"><a>FIFA 22 Oct 20, 2021</a></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-81">81</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-83">83</span></span> <abbr class="pure-u-7-24">Short Passing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-77">77</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-78">78</span></span> <abbr class="pure-u-7-24">Dribbling</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-82">82</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-83">83</span></span> <abbr class="pure-u-7-24">Long Passing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-79">79</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-80">80</span></span> <abbr class="pure-u-7-24">Ball Control</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-79">79</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-80">80</span></span> <abbr class="pure-u-7-24">Reactions</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-78">78</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-79">79</span></span> <abbr class="pure-u-7-24">Aggression</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-79">79</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-80">80</span></span> <abbr class="pure-u-7-24">Interceptions</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-79">79</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-81">81</span></span> <abbr class="pure-u-7-24">Standing Tackle</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-71">71</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-72">72</span></span> <abbr class="pure-u-7-24">Sliding Tackle</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-78">78</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-80">80</span></span> <abbr class="pure-u-7-24">Composure</abbr></div><div class="block-quarter pure-u-1-1"><abbr>and 12 more changes</abbr></div></div>
#  </div></div></td>
#  <td class="col-name">
#  <a class="tooltip" data-tooltip="Aurélien Tchouaméni" href="/player/241637/aurelien-tchouameni/220008/"><div class="bp3-text-overflow-ellipsis">A. Tchouaméni</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/fr.png" data-srcset="https://cdn.sofifa.com/flags/fr@2x.png 2x, https://cdn.sofifa.com/flags/fr@3x.png 3x" src="" title="France"/> <a href="/players?pn=14" rel="nofollow"><span class="pos pos14">CM</span></a> <a href="/players?pn=10" rel="nofollow"><span class="pos pos10">CDM</span></a></td><td class="col col-ae" data-col="ae">21</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-80">80</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-87">87</span></td><td class="col-name">
#  <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
#  <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/69/30.png" data-srcset="https://cdn.sofifa.com/teams/69/60.png 2x, https://cdn.sofifa.com/teams/69/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
#  </figure>
#  <a href="/team/69/as-monaco/">AS Monaco</a><div class="sub">
#  2020 ~ 2024</div>
#  </div>
#  </td><td class="col col-vl" data-col="vl">€42.5M</td><td class="col col-wg" data-col="wg">€43K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">2104</span></td></tr><tr>
#  <td class="col-avatar"><div class="popover popover-right">
#  <figure class="avatar updated ">
#  <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/235/212/22_60.png" data-srcset="https://cdn.sofifa.com/players/235/212/22_120.png 2x, https://cdn.sofifa.com/players/235/212/22_180.png 3x" data-type="player" id="235212" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure>
#  <div class="popover-container">
#  <div class="popover-arrow"></div>
#  <div class="bp3-callout"><div class="block-quarter half-spacing pure-u-1-1"><a>FIFA 22 Oct 20, 2021</a></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-73">73</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-75">75</span></span> <abbr class="pure-u-7-24">Finishing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-60">60</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-74">74</span></span> <abbr class="pure-u-7-24">Volleys</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-95">95</span> <span class="bp3-icon bp3-icon-arrow-bottom-right">↘</span> <span class="bp3-tag p p-93">93</span></span> <abbr class="pure-u-7-24">Acceleration</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-86">86</span> <span class="bp3-icon bp3-icon-arrow-bottom-right">↘</span> <span class="bp3-tag p p-84">84</span></span> <abbr class="pure-u-7-24">Agility</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-91">91</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-93">93</span></span> <abbr class="pure-u-7-24">Stamina</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-73">73</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-74">74</span></span> <abbr class="pure-u-7-24">Strength</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-78">78</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-79">79</span></span> <abbr class="pure-u-7-24">Positioning</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-75">75</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-78">78</span></span> <abbr class="pure-u-7-24">Vision</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-80">80</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-83">83</span></span> <abbr class="pure-u-7-24">Composure</abbr></div><div class="block-quarter pure-u-1-1"><abbr><del>Dives Into Tackles (AI)</del></abbr></div><div class="block-quarter pure-u-1-1"><abbr>and 11 more changes</abbr></div></div>
#  </div></div></td>
#  <td class="col-name">
#  <a class="tooltip" data-tooltip="Achraf Hakimi" href="/player/235212/achraf-hakimi/220008/"><div class="bp3-text-overflow-ellipsis">A. Hakimi</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/ma.png" data-srcset="https://cdn.sofifa.com/flags/ma@2x.png 2x, https://cdn.sofifa.com/flags/ma@3x.png 3x" src="" title="Morocco"/> <a href="/players?pn=3" rel="nofollow"><span class="pos pos3">RB</span></a> <a href="/players?pn=2" rel="nofollow"><span class="pos pos2">RWB</span></a></td><td class="col col-ae" data-col="ae">22</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-85">85</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-89">89</span></td><td class="col-name">
#  <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
#  <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/73/30.png" data-srcset="https://cdn.sofifa.com/teams/73/60.png 2x, https://cdn.sofifa.com/teams/73/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
#  </figure>
#  <a href="/team/73/paris-saint-germain/">Paris Saint-Germain</a><div class="sub">
#  2021 ~ 2026</div>
#  </div>
#  </td><td class="col col-vl" data-col="vl">€73M</td><td class="col col-wg" data-col="wg">€100K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">2207</span></td></tr><tr>
#  <td class="col-avatar"><div class="popover popover-right">
#  <figure class="avatar updated ">
#  <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/256/287/22_60.png" data-srcset="https://cdn.sofifa.com/players/256/287/22_120.png 2x, https://cdn.sofifa.com/players/256/287/22_180.png 3x" data-type="player" id="256287" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure>
#  <div class="popover-container">
#  <div class="popover-arrow"></div>
#  <div class="bp3-callout"><div class="block-quarter half-spacing pure-u-1-1"><a>FIFA 22 Oct 20, 2021</a></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-72">72</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-73">73</span></span> <abbr class="pure-u-7-24">Finishing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-68">68</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-72">72</span></span> <abbr class="pure-u-7-24">Short Passing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-75">75</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-78">78</span></span> <abbr class="pure-u-7-24">Dribbling</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-61">61</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-63">63</span></span> <abbr class="pure-u-7-24">Curve</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-66">66</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-70">70</span></span> <abbr class="pure-u-7-24">Long Passing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-74">74</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-77">77</span></span> <abbr class="pure-u-7-24">Ball Control</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-89">89</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-90">90</span></span> <abbr class="pure-u-7-24">Acceleration</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-77">77</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-79">79</span></span> <abbr class="pure-u-7-24">Sprint Speed</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-89">89</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-90">90</span></span> <abbr class="pure-u-7-24">Balance</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-73">73</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-76">76</span></span> <abbr class="pure-u-7-24">Shot Power</abbr></div><div class="block-quarter pure-u-1-1"><abbr>and 20 more changes</abbr></div></div>
#  </div></div></td>
#  <td class="col-name">
#  <a class="tooltip" data-tooltip="Facundo Farías" href="/player/256287/facundo-farias/220008/"><div class="bp3-text-overflow-ellipsis">F. Farías</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/ar.png" data-srcset="https://cdn.sofifa.com/flags/ar@2x.png 2x, https://cdn.sofifa.com/flags/ar@3x.png 3x" src="" title="Argentina"/> <a href="/players?pn=25" rel="nofollow"><span class="pos pos25">ST</span></a> <a href="/players?pn=21" rel="nofollow"><span class="pos pos21">CF</span></a></td><td class="col col-ae" data-col="ae">18</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-73">73</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-85">85</span></td><td class="col-name">
#  <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
#  <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/110406/30.png" data-srcset="https://cdn.sofifa.com/teams/110406/60.png 2x, https://cdn.sofifa.com/teams/110406/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
#  </figure>
#  <a href="/team/110406/club-atletico-colon/">Club Atlético Colón</a><div class="sub">
#  2020 ~ 2023</div>
#  </div>
#  </td><td class="col col-vl" data-col="vl">€7M</td><td class="col col-wg" data-col="wg">€5K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">1888</span></td></tr><tr>
#  <td class="col-avatar"><div class="popover popover-right">
#  <figure class="avatar updated ">
#  <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/213/661/22_60.png" data-srcset="https://cdn.sofifa.com/players/213/661/22_120.png 2x, https://cdn.sofifa.com/players/213/661/22_180.png 3x" data-type="player" id="213661" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure>
#  <div class="popover-container">
#  <div class="popover-arrow"></div>
#  <div class="bp3-callout"><div class="block-quarter half-spacing pure-u-1-1"><a>FIFA 22 Oct 20, 2021</a></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-66">66</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-67">67</span></span> <abbr class="pure-u-7-24">Dribbling</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-71">71</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-72">72</span></span> <abbr class="pure-u-7-24">Long Passing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-73">73</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-74">74</span></span> <abbr class="pure-u-7-24">Ball Control</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-69">69</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-75">75</span></span> <abbr class="pure-u-7-24">Sprint Speed</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-79">79</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-82">82</span></span> <abbr class="pure-u-7-24">Reactions</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-75">75</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-78">78</span></span> <abbr class="pure-u-7-24">Jumping</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-73">73</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-74">74</span></span> <abbr class="pure-u-7-24">Strength</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-73">73</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-74">74</span></span> <abbr class="pure-u-7-24">Aggression</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-82">82</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-84">84</span></span> <abbr class="pure-u-7-24">Interceptions</abbr></div><div class="block-quarter pure-g"><abbr class="pure-u-7-24">Height</abbr> <span class="pure-u-17-24">187cm <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> 188cm</span></div><div class="block-quarter pure-u-1-1"><abbr>and 13 more changes</abbr></div></div>
#  </div></div></td>
#  <td class="col-name">
#  <a class="tooltip" data-tooltip="Andreas Christensen" href="/player/213661/andreas-christensen/220008/"><div class="bp3-text-overflow-ellipsis">A. Christensen</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/dk.png" data-srcset="https://cdn.sofifa.com/flags/dk@2x.png 2x, https://cdn.sofifa.com/flags/dk@3x.png 3x" src="" title="Denmark"/> <a href="/players?pn=5" rel="nofollow"><span class="pos pos5">CB</span></a></td><td class="col col-ae" data-col="ae">25</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-81">81</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-85">85</span></td><td class="col-name">
#  <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
#  <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/5/30.png" data-srcset="https://cdn.sofifa.com/teams/5/60.png 2x, https://cdn.sofifa.com/teams/5/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
#  </figure>
#  <a href="/team/5/chelsea/">Chelsea</a><div class="sub">
#  2013 ~ 2022</div>
#  </div>
#  </td><td class="col col-vl" data-col="vl">€32M</td><td class="col col-wg" data-col="wg">€100K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">1753</span></td></tr><tr>
#  <td class="col-avatar"><div class="popover popover-right">
#  <figure class="avatar updated ">
#  <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/224/081/22_60.png" data-srcset="https://cdn.sofifa.com/players/224/081/22_120.png 2x, https://cdn.sofifa.com/players/224/081/22_180.png 3x" data-type="player" id="224081" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure>
#  <div class="popover-container">
#  <div class="popover-arrow"></div>
#  <div class="bp3-callout"><div class="block-quarter half-spacing pure-u-1-1"><a>FIFA 22 Oct 20, 2021</a></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-65">65</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-66">66</span></span> <abbr class="pure-u-7-24">Heading Accuracy</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-80">80</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-82">82</span></span> <abbr class="pure-u-7-24">Short Passing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-79">79</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-80">80</span></span> <abbr class="pure-u-7-24">Ball Control</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-66">66</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-67">67</span></span> <abbr class="pure-u-7-24">Sprint Speed</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-85">85</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-86">86</span></span> <abbr class="pure-u-7-24">Stamina</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-67">67</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-68">68</span></span> <abbr class="pure-u-7-24">Long Shots</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-77">77</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-78">78</span></span> <abbr class="pure-u-7-24">Interceptions</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-74">74</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-75">75</span></span> <abbr class="pure-u-7-24">Vision</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-79">79</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-80">80</span></span> <abbr class="pure-u-7-24">Marking</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-77">77</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-78">78</span></span> <abbr class="pure-u-7-24">Sliding Tackle</abbr></div><div class="block-quarter pure-u-1-1"><abbr>and 11 more changes</abbr></div></div>
#  </div></div></td>
#  <td class="col-name">
#  <a class="tooltip" data-tooltip="Kalvin Phillips" href="/player/224081/kalvin-phillips/220008/"><div class="bp3-text-overflow-ellipsis">K. Phillips</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/gb-eng.png" data-srcset="https://cdn.sofifa.com/flags/gb-eng@2x.png 2x, https://cdn.sofifa.com/flags/gb-eng@3x.png 3x" src="" title="England"/> <a href="/players?pn=10" rel="nofollow"><span class="pos pos10">CDM</span></a> <a href="/players?pn=14" rel="nofollow"><span class="pos pos14">CM</span></a> <a href="/players?pn=5" rel="nofollow"><span class="pos pos5">CB</span></a></td><td class="col col-ae" data-col="ae">25</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-81">81</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-85">85</span></td><td class="col-name">
#  <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
#  <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/8/30.png" data-srcset="https://cdn.sofifa.com/teams/8/60.png 2x, https://cdn.sofifa.com/teams/8/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
#  </figure>
#  <a href="/team/8/leeds-united/">Leeds United</a><div class="sub">
#  2014 ~ 2024</div>
#  </div>
#  </td><td class="col col-vl" data-col="vl">€32.5M</td><td class="col col-wg" data-col="wg">€82K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">2101</span></td></tr><tr>
#  <td class="col-avatar"><div class="popover popover-right">
#  <figure class="avatar updated ">
#  <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/248/808/22_60.png" data-srcset="https://cdn.sofifa.com/players/248/808/22_120.png 2x, https://cdn.sofifa.com/players/248/808/22_180.png 3x" data-type="player" id="248808" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure>
#  <div class="popover-container">
#  <div class="popover-arrow"></div>
#  <div class="bp3-callout"><div class="block-quarter half-spacing pure-u-1-1"><a>FIFA 22 Oct 20, 2021</a></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-68">68</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-70">70</span></span> <abbr class="pure-u-7-24">Crossing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-65">65</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-68">68</span></span> <abbr class="pure-u-7-24">Short Passing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-66">66</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-68">68</span></span> <abbr class="pure-u-7-24">Dribbling</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-68">68</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-69">69</span></span> <abbr class="pure-u-7-24">Long Passing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-68">68</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-70">70</span></span> <abbr class="pure-u-7-24">Ball Control</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-70">70</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-74">74</span></span> <abbr class="pure-u-7-24">Acceleration</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-68">68</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-72">72</span></span> <abbr class="pure-u-7-24">Sprint Speed</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-68">68</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-72">72</span></span> <abbr class="pure-u-7-24">Agility</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-61">61</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-63">63</span></span> <abbr class="pure-u-7-24">Reactions</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-56">56</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-58">58</span></span> <abbr class="pure-u-7-24">Shot Power</abbr></div><div class="block-quarter pure-u-1-1"><abbr>and 21 more changes</abbr></div></div>
#  </div></div></td>
#  <td class="col-name">
#  <a class="tooltip" data-tooltip="Aaron Hickey" href="/player/248808/aaron-hickey/220008/"><div class="bp3-text-overflow-ellipsis">A. Hickey</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/gb-sct.png" data-srcset="https://cdn.sofifa.com/flags/gb-sct@2x.png 2x, https://cdn.sofifa.com/flags/gb-sct@3x.png 3x" src="" title="Scotland"/> <a href="/players?pn=7" rel="nofollow"><span class="pos pos7">LB</span></a> <a href="/players?pn=3" rel="nofollow"><span class="pos pos3">RB</span></a></td><td class="col col-ae" data-col="ae">19</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-71">71</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-84">84</span></td><td class="col-name">
#  <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
#  <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/189/30.png" data-srcset="https://cdn.sofifa.com/teams/189/60.png 2x, https://cdn.sofifa.com/teams/189/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
#  </figure>
#  <a href="/team/189/bologna/">Bologna</a><div class="sub">
#  2020 ~ 2024</div>
#  </div>
#  </td><td class="col col-vl" data-col="vl">€4.3M</td><td class="col col-wg" data-col="wg">€9K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">1800</span></td></tr><tr>
#  <td class="col-avatar"><figure class="avatar">
#  <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/241/202/22_60.png" data-srcset="https://cdn.sofifa.com/players/241/202/22_120.png 2x, https://cdn.sofifa.com/players/241/202/22_180.png 3x" data-type="player" id="241202" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure></td>
#  <td class="col-name">
#  <a class="tooltip" data-tooltip="Patson Daka" href="/player/241202/patson-daka/220008/"><div class="bp3-text-overflow-ellipsis">P. Daka</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/zm.png" data-srcset="https://cdn.sofifa.com/flags/zm@2x.png 2x, https://cdn.sofifa.com/flags/zm@3x.png 3x" src="" title="Zambia"/> <a href="/players?pn=25" rel="nofollow"><span class="pos pos25">ST</span></a></td><td class="col col-ae" data-col="ae">22</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-77">77</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-84">84</span></td><td class="col-name">
#  <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
#  <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/95/30.png" data-srcset="https://cdn.sofifa.com/teams/95/60.png 2x, https://cdn.sofifa.com/teams/95/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
#  </figure>
#  <a href="/team/95/leicester-city/">Leicester City</a><div class="sub">
#  2021 ~ 2026</div>
#  </div>
#  </td><td class="col col-vl" data-col="vl">€21.5M</td><td class="col col-wg" data-col="wg">€78K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">1848</span></td></tr><tr>
#  <td class="col-avatar"><div class="popover popover-right">
#  <figure class="avatar updated ">
#  <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/233/927/22_60.png" data-srcset="https://cdn.sofifa.com/players/233/927/22_120.png 2x, https://cdn.sofifa.com/players/233/927/22_180.png 3x" data-type="player" id="233927" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure>
#  <div class="popover-container">
#  <div class="popover-arrow"></div>
#  <div class="bp3-callout"><div class="block-quarter half-spacing pure-u-1-1"><a>FIFA 22 Oct 20, 2021</a></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-60">60</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-66">66</span></span> <abbr class="pure-u-7-24">Heading Accuracy</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-84">84</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-86">86</span></span> <abbr class="pure-u-7-24">Ball Control</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-81">81</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-82">82</span></span> <abbr class="pure-u-7-24">Overall Rating</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-86">86</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-87">87</span></span> <abbr class="pure-u-7-24">Potential</abbr></div></div>
#  </div></div></td>
#  <td class="col-name">
#  <a class="tooltip" data-tooltip="Lucas Tolentino Coelho de Lima" href="/player/233927/lucas-tolentino-coelho-de-lima/220008/"><div class="bp3-text-overflow-ellipsis">Lucas Paquetá</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/br.png" data-srcset="https://cdn.sofifa.com/flags/br@2x.png 2x, https://cdn.sofifa.com/flags/br@3x.png 3x" src="" title="Brazil"/> <a href="/players?pn=18" rel="nofollow"><span class="pos pos18">CAM</span></a> <a href="/players?pn=14" rel="nofollow"><span class="pos pos14">CM</span></a></td><td class="col col-ae" data-col="ae">23</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-82">82</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-87">87</span></td><td class="col-name">
#  <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
#  <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/66/30.png" data-srcset="https://cdn.sofifa.com/teams/66/60.png 2x, https://cdn.sofifa.com/teams/66/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
#  </figure>
#  <a href="/team/66/olympique-lyonnais/">Olympique Lyonnais</a><div class="sub">
#  2020 ~ 2025</div>
#  </div>
#  </td><td class="col col-vl" data-col="vl">€46M</td><td class="col col-wg" data-col="wg">€70K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">2204</span></td></tr><tr>
#  <td class="col-avatar"><div class="popover popover-right">
#  <figure class="avatar updated ">
#  <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/232/411/22_60.png" data-srcset="https://cdn.sofifa.com/players/232/411/22_120.png 2x, https://cdn.sofifa.com/players/232/411/22_180.png 3x" data-type="player" id="232411" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure>
#  <div class="popover-container">
#  <div class="popover-arrow"></div>
#  <div class="bp3-callout"><div class="block-quarter half-spacing pure-u-1-1"><a>FIFA 22 Oct 20, 2021</a></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-74">74</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-79">79</span></span> <abbr class="pure-u-7-24">Finishing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-59">59</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-62">62</span></span> <abbr class="pure-u-7-24">Heading Accuracy</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-76">76</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-78">78</span></span> <abbr class="pure-u-7-24">FK Accuracy</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-78">78</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-79">79</span></span> <abbr class="pure-u-7-24">Reactions</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-76">76</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-77">77</span></span> <abbr class="pure-u-7-24">Long Shots</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-78">78</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-82">82</span></span> <abbr class="pure-u-7-24">Positioning</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-81">81</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-82">82</span></span> <abbr class="pure-u-7-24">Overall Rating</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-86">86</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-87">87</span></span> <abbr class="pure-u-7-24">Potential</abbr></div></div>
#  </div></div></td>
#  <td class="col-name">
#  <a class="tooltip" data-tooltip="Christopher Nkunku" href="/player/232411/christopher-nkunku/220008/"><div class="bp3-text-overflow-ellipsis">C. Nkunku</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/fr.png" data-srcset="https://cdn.sofifa.com/flags/fr@2x.png 2x, https://cdn.sofifa.com/flags/fr@3x.png 3x" src="" title="France"/> <a href="/players?pn=18" rel="nofollow"><span class="pos pos18">CAM</span></a> <a href="/players?pn=14" rel="nofollow"><span class="pos pos14">CM</span></a> <a href="/players?pn=21" rel="nofollow"><span class="pos pos21">CF</span></a></td><td class="col col-ae" data-col="ae">23</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-82">82</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-87">87</span></td><td class="col-name">
#  <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
#  <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/112172/30.png" data-srcset="https://cdn.sofifa.com/teams/112172/60.png 2x, https://cdn.sofifa.com/teams/112172/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
#  </figure>
#  <a href="/team/112172/rb-leipzig/">RB Leipzig</a><div class="sub">
#  2019 ~ 2024</div>
#  </div>
#  </td><td class="col col-vl" data-col="vl">€46M</td><td class="col col-wg" data-col="wg">€78K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">2143</span></td></tr><tr>
#  <td class="col-avatar"><div class="popover popover-right">
#  <figure class="avatar updated ">
#  <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/246/191/22_60.png" data-srcset="https://cdn.sofifa.com/players/246/191/22_120.png 2x, https://cdn.sofifa.com/players/246/191/22_180.png 3x" data-type="player" id="246191" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure>
#  <div class="popover-container">
#  <div class="popover-arrow"></div>
#  <div class="bp3-callout"><div class="block-quarter half-spacing pure-u-1-1"><a>FIFA 22 Oct 20, 2021</a></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-71">71</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-73">73</span></span> <abbr class="pure-u-7-24">Crossing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-75">75</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-76">76</span></span> <abbr class="pure-u-7-24">Finishing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-73">73</span> <span class="bp3-icon bp3-icon-arrow-bottom-right">↘</span> <span class="bp3-tag p p-71">71</span></span> <abbr class="pure-u-7-24">Short Passing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-69">69</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-70">70</span></span> <abbr class="pure-u-7-24">Volleys</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-72">72</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-76">76</span></span> <abbr class="pure-u-7-24">Dribbling</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-67">67</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-70">70</span></span> <abbr class="pure-u-7-24">Long Passing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-76">76</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-79">79</span></span> <abbr class="pure-u-7-24">Ball Control</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-86">86</span> <span class="bp3-icon bp3-icon-arrow-bottom-right">↘</span> <span class="bp3-tag p p-84">84</span></span> <abbr class="pure-u-7-24">Sprint Speed</abbr></div><div class="block-quarter pure-g"><abbr class="pure-u-7-24">Position 2</abbr> <span class="pure-u-17-24"><span class="pos pos21">CF</span> <span class="bp3-icon bp3-icon-arrow-right">→</span> <span class="pos pos25">ST</span></span></div><div class="block-quarter pure-g"><abbr class="pure-u-7-24">Weak Foot</abbr> <span class="pure-u-17-24">3 <span class="bp3-icon bp3-icon-star">★</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> 4 <span class="bp3-icon bp3-icon-star">★</span></span></div><div class="block-quarter pure-u-1-1"><abbr>and 24 more changes</abbr></div></div>
#  </div></div></td>
#  <td class="col-name">
#  <a class="tooltip" data-tooltip="Julián Álvarez" href="/player/246191/julian-alvarez/220008/"><div class="bp3-text-overflow-ellipsis">J. Álvarez</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/ar.png" data-srcset="https://cdn.sofifa.com/flags/ar@2x.png 2x, https://cdn.sofifa.com/flags/ar@3x.png 3x" src="" title="Argentina"/> <a href="/players?pn=23" rel="nofollow"><span class="pos pos23">RW</span></a> <a href="/players?pn=25" rel="nofollow"><span class="pos pos25">ST</span></a></td><td class="col col-ae" data-col="ae">21</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-76">76</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-85">85</span></td><td class="col-name">
#  <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
#  <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/1876/30.png" data-srcset="https://cdn.sofifa.com/teams/1876/60.png 2x, https://cdn.sofifa.com/teams/1876/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
#  </figure>
#  <a href="/team/1876/river-plate/">River Plate</a><div class="sub">
#  2018 ~ 2022</div>
#  </div>
#  </td><td class="col col-vl" data-col="vl">€17M</td><td class="col col-wg" data-col="wg">€14K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">2011</span></td></tr><tr>
#  <td class="col-avatar"><div class="popover popover-right">
#  <figure class="avatar updated ">
#  <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/256/008/22_60.png" data-srcset="https://cdn.sofifa.com/players/256/008/22_120.png 2x, https://cdn.sofifa.com/players/256/008/22_180.png 3x" data-type="player" id="256008" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure>
#  <div class="popover-container">
#  <div class="popover-arrow"></div>
#  <div class="bp3-callout"><div class="block-quarter half-spacing pure-u-1-1"><a>FIFA 22 Oct 20, 2021</a></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-69">69</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-73">73</span></span> <abbr class="pure-u-7-24">Standing Tackle</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-63">63</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-68">68</span></span> <abbr class="pure-u-7-24">Sliding Tackle</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-68">68</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-70">70</span></span> <abbr class="pure-u-7-24">Overall Rating</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-84">84</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-86">86</span></span> <abbr class="pure-u-7-24">Potential</abbr></div></div>
#  </div></div></td>
#  <td class="col-name">
#  <a class="tooltip" data-tooltip="Felipe Rodrigues da Silva" href="/player/256008/felipe-rodrigues-da-silva/220008/"><div class="bp3-text-overflow-ellipsis">Morato</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/br.png" data-srcset="https://cdn.sofifa.com/flags/br@2x.png 2x, https://cdn.sofifa.com/flags/br@3x.png 3x" src="" title="Brazil"/> <a href="/players?pn=5" rel="nofollow"><span class="pos pos5">CB</span></a></td><td class="col col-ae" data-col="ae">20</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-70">70</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-86">86</span></td><td class="col-name">
#  <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
#  <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/234/30.png" data-srcset="https://cdn.sofifa.com/teams/234/60.png 2x, https://cdn.sofifa.com/teams/234/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
#  </figure>
#  <a href="/team/234/sl-benfica/">SL Benfica</a><div class="sub">
#  2019 ~ 2024</div>
#  </div>
#  </td><td class="col col-vl" data-col="vl">€3.9M</td><td class="col col-wg" data-col="wg">€5K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">1561</span></td></tr><tr>
#  <td class="col-avatar"><figure class="avatar">
#  <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/251/852/22_60.png" data-srcset="https://cdn.sofifa.com/players/251/852/22_120.png 2x, https://cdn.sofifa.com/players/251/852/22_180.png 3x" data-type="player" id="251852" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure></td>
#  <td class="col-name">
#  <a class="tooltip" data-tooltip="Karim Adeyemi" href="/player/251852/karim-adeyemi/220008/"><div class="bp3-text-overflow-ellipsis">K. Adeyemi</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/de.png" data-srcset="https://cdn.sofifa.com/flags/de@2x.png 2x, https://cdn.sofifa.com/flags/de@3x.png 3x" src="" title="Germany"/> <a href="/players?pn=25" rel="nofollow"><span class="pos pos25">ST</span></a></td><td class="col col-ae" data-col="ae">19</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-72">72</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-86">86</span></td><td class="col-name">
#  <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
#  <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/191/30.png" data-srcset="https://cdn.sofifa.com/teams/191/60.png 2x, https://cdn.sofifa.com/teams/191/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
#  </figure>
#  <a href="/team/191/fc-red-bull-salzburg/">FC Red Bull Salzburg</a><div class="sub">
#  2018 ~ 2024</div>
#  </div>
#  </td><td class="col col-vl" data-col="vl">€5.5M</td><td class="col col-wg" data-col="wg">€13K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">1851</span></td></tr><tr>
#  <td class="col-avatar"><div class="popover popover-right">
#  <figure class="avatar updated ">
#  <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/264/240/22_60.png" data-srcset="https://cdn.sofifa.com/players/264/240/22_120.png 2x, https://cdn.sofifa.com/players/264/240/22_180.png 3x" data-type="player" id="264240" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure>
#  <div class="popover-container">
#  <div class="popover-arrow"></div>
#  <div class="bp3-callout"><div class="block-quarter half-spacing pure-u-1-1"><a>FIFA 22 Oct 20, 2021</a></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-68">68</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-75">75</span></span> <abbr class="pure-u-7-24">Aggression</abbr></div><div class="block-half pure-g"><abbr class="pure-u-7-24">Attacking Work Rate</abbr> <span class="pure-u-17-24">Medium <span class="bp3-icon bp3-icon-arrow-right">→</span> High</span></div><div class="block-half pure-g"><abbr class="pure-u-7-24">Defensive Work Rate</abbr> <span class="pure-u-17-24">Medium <span class="bp3-icon bp3-icon-arrow-right">→</span> High</span></div></div>
#  </div></div></td>
#  <td class="col-name">
# ...
#  <td class="col-avatar"><figure class="avatar">
#  <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/251/804/22_60.png" data-srcset="https://cdn.sofifa.com/players/251/804/22_120.png 2x, https://cdn.sofifa.com/players/251/804/22_180.png 3x" data-type="player" id="251804" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure></td>
#  <td class="col-name">
#  <a class="tooltip" data-tooltip="Sergiño Dest" href="/player/251804/sergino-dest/220008/"><div class="bp3-text-overflow-ellipsis">S. Dest</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/us.png" data-srcset="https://cdn.sofifa.com/flags/us@2x.png 2x, https://cdn.sofifa.com/flags/us@3x.png 3x" src="" title="United States"/> <a href="/players?pn=3" rel="nofollow"><span class="pos pos3">RB</span></a> <a href="/players?pn=12" rel="nofollow"><span class="pos pos12">RM</span></a></td><td class="col col-ae" data-col="ae">20</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-76">76</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-85">85</span></td><td class="col-name">
#  <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
#  <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/241/30.png" data-srcset="https://cdn.sofifa.com/teams/241/60.png 2x, https://cdn.sofifa.com/teams/241/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
#  </figure>
#  <a href="/team/241/fc-barcelona/">FC Barcelona</a><div class="sub">
#  2020 ~ 2025</div>
#  </div>
#  </td><td class="col col-vl" data-col="vl">€15.5M</td><td class="col col-wg" data-col="wg">€67K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">1974</span></td></tr><tr>
#  <td class="col-avatar"><div class="popover popover-right">
#  <figure class="avatar updated ">
#  <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/233/419/22_60.png" data-srcset="https://cdn.sofifa.com/players/233/419/22_120.png 2x, https://cdn.sofifa.com/players/233/419/22_180.png 3x" data-type="player" id="233419" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure>
#  <div class="popover-container">
#  <div class="popover-arrow"></div>
#  <div class="bp3-callout"><div class="block-quarter half-spacing pure-u-1-1"><a>FIFA 22 Oct 20, 2021</a></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-74">74</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-75">75</span></span> <abbr class="pure-u-7-24">Finishing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-81">81</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-82">82</span></span> <abbr class="pure-u-7-24">Shot Power</abbr></div></div>
#  </div></div></td>
#  <td class="col-name">
#  <a class="tooltip" data-tooltip="Raphael Dias Belloli" href="/player/233419/raphael-dias-belloli/220008/"><div class="bp3-text-overflow-ellipsis">Raphinha</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/br.png" data-srcset="https://cdn.sofifa.com/flags/br@2x.png 2x, https://cdn.sofifa.com/flags/br@3x.png 3x" src="" title="Brazil"/> <a href="/players?pn=12" rel="nofollow"><span class="pos pos12">RM</span></a> <a href="/players?pn=23" rel="nofollow"><span class="pos pos23">RW</span></a></td><td class="col col-ae" data-col="ae">24</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-82">82</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-87">87</span></td><td class="col-name">
#  <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
#  <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/8/30.png" data-srcset="https://cdn.sofifa.com/teams/8/60.png 2x, https://cdn.sofifa.com/teams/8/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
#  </figure>
#  <a href="/team/8/leeds-united/">Leeds United</a><div class="sub">
#  2020 ~ 2024</div>
#  </div>
#  </td><td class="col col-vl" data-col="vl">€46M</td><td class="col col-wg" data-col="wg">€89K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">2102</span></td></tr><tr>
#  <td class="col-avatar"><figure class="avatar">
#  <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/248/243/22_60.png" data-srcset="https://cdn.sofifa.com/players/248/243/22_120.png 2x, https://cdn.sofifa.com/players/248/243/22_180.png 3x" data-type="player" id="248243" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure></td>
#  <td class="col-name">
#  <a class="tooltip" data-tooltip="Eduardo Camavinga" href="/player/248243/eduardo-camavinga/220008/"><div class="bp3-text-overflow-ellipsis">E. Camavinga</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/fr.png" data-srcset="https://cdn.sofifa.com/flags/fr@2x.png 2x, https://cdn.sofifa.com/flags/fr@3x.png 3x" src="" title="France"/> <a href="/players?pn=14" rel="nofollow"><span class="pos pos14">CM</span></a> <a href="/players?pn=10" rel="nofollow"><span class="pos pos10">CDM</span></a></td><td class="col col-ae" data-col="ae">18</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-78">78</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-89">89</span></td><td class="col-name">
#  <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
#  <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/243/30.png" data-srcset="https://cdn.sofifa.com/teams/243/60.png 2x, https://cdn.sofifa.com/teams/243/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
#  </figure>
#  <a href="/team/243/real-madrid-cf/">Real Madrid CF</a><div class="sub">
#  2021 ~ 2027</div>
#  </div>
#  </td><td class="col col-vl" data-col="vl">€29.5M</td><td class="col col-wg" data-col="wg">€44K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">2089</span></td></tr><tr>
#  <td class="col-avatar"><figure class="avatar">
#  <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/233/049/22_60.png" data-srcset="https://cdn.sofifa.com/players/233/049/22_120.png 2x, https://cdn.sofifa.com/players/233/049/22_180.png 3x" data-type="player" id="233049" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure></td>
#  <td class="col-name">
#  <a class="tooltip" data-tooltip="Jadon Sancho" href="/player/233049/jadon-sancho/220008/"><div class="bp3-text-overflow-ellipsis">J. Sancho</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/gb-eng.png" data-srcset="https://cdn.sofifa.com/flags/gb-eng@2x.png 2x, https://cdn.sofifa.com/flags/gb-eng@3x.png 3x" src="" title="England"/> <a href="/players?pn=12" rel="nofollow"><span class="pos pos12">RM</span></a> <a href="/players?pn=21" rel="nofollow"><span class="pos pos21">CF</span></a> <a href="/players?pn=16" rel="nofollow"><span class="pos pos16">LM</span></a></td><td class="col col-ae" data-col="ae">21</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-87">87</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-91">91</span></td><td class="col-name">
#  <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
#  <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/11/30.png" data-srcset="https://cdn.sofifa.com/teams/11/60.png 2x, https://cdn.sofifa.com/teams/11/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
#  </figure>
#  <a href="/team/11/manchester-united/">Manchester United</a><div class="sub">
#  2021 ~ 2026</div>
#  </div>
#  </td><td class="col col-vl" data-col="vl">€116.5M</td><td class="col col-wg" data-col="wg">€150K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">2007</span></td></tr><tr>
#  <td class="col-avatar"><div class="popover popover-right">
#  <figure class="avatar updated ">
#  <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/243/576/22_60.png" data-srcset="https://cdn.sofifa.com/players/243/576/22_120.png 2x, https://cdn.sofifa.com/players/243/576/22_180.png 3x" data-type="player" id="243576" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure>
#  <div class="popover-container">
#  <div class="popover-arrow"></div>
#  <div class="bp3-callout"><div class="block-quarter half-spacing pure-u-1-1"><a>FIFA 22 Oct 20, 2021</a></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-53">53</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-60">60</span></span> <abbr class="pure-u-7-24">Volleys</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-76">76</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-77">77</span></span> <abbr class="pure-u-7-24">Acceleration</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-81">81</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-83">83</span></span> <abbr class="pure-u-7-24">Shot Power</abbr></div></div>
#  </div></div></td>
#  <td class="col-name">
#  <a class="tooltip" data-tooltip="Pedro Antonio Porro Sauceda" href="/player/243576/pedro-antonio-porro-sauceda/220008/"><div class="bp3-text-overflow-ellipsis">Pedro Porro</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/es.png" data-srcset="https://cdn.sofifa.com/flags/es@2x.png 2x, https://cdn.sofifa.com/flags/es@3x.png 3x" src="" title="Spain"/> <a href="/players?pn=2" rel="nofollow"><span class="pos pos2">RWB</span></a> <a href="/players?pn=12" rel="nofollow"><span class="pos pos12">RM</span></a></td><td class="col col-ae" data-col="ae">21</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-80">80</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-87">87</span></td><td class="col-name">
#  <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
#  <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/237/30.png" data-srcset="https://cdn.sofifa.com/teams/237/60.png 2x, https://cdn.sofifa.com/teams/237/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
#  </figure>
#  <a href="/team/237/sporting-cp/">Sporting CP</a><div class="sub">
#  Jun 30, 2022 <span class="bp3-tag bp3-minimal bp3-intent-success">On Loan</span></div>
#  </div>
#  </td><td class="col col-vl" data-col="vl">€40.5M</td><td class="col col-wg" data-col="wg">€80K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">2079</span></td></tr><tr>
#  <td class="col-avatar"><div class="popover popover-right">
#  <figure class="avatar updated ">
#  <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/222/227/22_60.png" data-srcset="https://cdn.sofifa.com/players/222/227/22_120.png 2x, https://cdn.sofifa.com/players/222/227/22_180.png 3x" data-type="player" id="222227" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure>
#  <div class="popover-container">
#  <div class="popover-arrow"></div>
#  <div class="bp3-callout"><div class="block-quarter half-spacing pure-u-1-1"><a>FIFA 22 Oct 20, 2021</a></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-45">45</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-52">52</span></span> <abbr class="pure-u-7-24">Heading Accuracy</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-77">77</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-78">78</span></span> <abbr class="pure-u-7-24">Short Passing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-74">74</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-75">75</span></span> <abbr class="pure-u-7-24">Long Passing</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-73">73</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-74">74</span></span> <abbr class="pure-u-7-24">Ball Control</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-58">58</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-65">65</span></span> <abbr class="pure-u-7-24">Jumping</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-63">63</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-65">65</span></span> <abbr class="pure-u-7-24">Aggression</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-69">69</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-71">71</span></span> <abbr class="pure-u-7-24">Interceptions</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-67">67</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-70">70</span></span> <abbr class="pure-u-7-24">Marking</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-66">66</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-69">69</span></span> <abbr class="pure-u-7-24">Standing Tackle</abbr></div><div class="block-quarter pure-g"><span class="pure-u-17-24"><span class="bp3-tag p p-62">62</span> <span class="bp3-icon bp3-icon-arrow-top-right">↗</span> <span class="bp3-tag p p-65">65</span></span> <abbr class="pure-u-7-24">Sliding Tackle</abbr></div><div class="block-quarter pure-u-1-1"><abbr>and 12 more changes</abbr></div></div>
#  </div></div></td>
#  <td class="col-name">
#  <a class="tooltip" data-tooltip="Patrick Berg" href="/player/222227/patrick-berg/220008/"><div class="bp3-text-overflow-ellipsis">P. Berg</div></a><img alt="" class="flag" data-src="https://cdn.sofifa.com/flags/no.png" data-srcset="https://cdn.sofifa.com/flags/no@2x.png 2x, https://cdn.sofifa.com/flags/no@3x.png 3x" src="" title="Norway"/> <a href="/players?pn=14" rel="nofollow"><span class="pos pos14">CM</span></a> <a href="/players?pn=10" rel="nofollow"><span class="pos pos10">CDM</span></a></td><td class="col col-ae" data-col="ae">23</td><td class="col col-oa" data-col="oa"><span class="bp3-tag p p-74">74</span></td><td class="col col-pt" data-col="pt"><span class="bp3-tag p p-82">82</span></td><td class="col-name">
#  <div class="bp3-text-overflow-ellipsis"><figure class="avatar avatar-sm transparent">
#  <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/918/30.png" data-srcset="https://cdn.sofifa.com/teams/918/60.png 2x, https://cdn.sofifa.com/teams/918/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
#  </figure>
#  <a href="/team/918/fk-bodoglimt/">FK Bodø/Glimt</a><div class="sub">
#  2014 ~ 2021</div>
#  </div>
#  </td><td class="col col-vl" data-col="vl">€9.5M</td><td class="col col-wg" data-col="wg">€5K</td><td class="col col-tt" data-col="tt"><span class="bp3-tag p">1983</span></td></tr></tbody>]

# %%
names01 = sumitsoup01.find('a', class_ = "tooltip").text

# %%
names01
# Out:
# 'A. Tchouaméni'

# %%
age01 = sumitsoup01.find('td', class_= "col col-ae"  ).text.replace('\n', '')

# %%
age01
# Out:
# '21'

# %%
overall_rating01 = sumitsoup01.find('td', class_="col col-oa").text.replace('\n', '')

# %%
overall_rating01
# Out:
# '80'

# %%
potential01 = sumitsoup01.find('td', class_="col col-pt" ).text.replace('\n', '')

# %%
potential01
# Out:
# '87'

# %%
team_name01 = sumitsoup01.find('div', attrs = {'class': 'bp3-text-overflow-ellipsis'}).text.replace('\n', '')

# %%
team_name01
# Out:
# 'A. Tchouaméni'

# %%
contract_year01 = sumitsoup01.find('div', class_ = "sub").text.replace('\n', '')

# %%
contract_year01
# Out:
# '2020 ~ 2024'

# %%
value01 = sumitsoup01.find('td', class_ = "col col-vl").text.replace('\n', '')

# %%
value01
# Out:
# '€42.5M'

# %%
wage01 = sumitsoup01.find('td', class_ = "col col-wg").text.replace('\n', '')

# %%
wage01
# Out:
# '€43K'

# %%
total_stats01 = sumitsoup01.find('span', class_ = "bp3-tag p").text.replace('\n', '')

# %%
total_stats01
# Out:
# '2104'

# %%
for i in range(0,600,60):
  print(f'https://sofifa.com/players?offset={i}')
# Out:
# https://sofifa.com/players?offset=0
# https://sofifa.com/players?offset=60
# https://sofifa.com/players?offset=120
# https://sofifa.com/players?offset=180
# https://sofifa.com/players?offset=240
# https://sofifa.com/players?offset=300
# https://sofifa.com/players?offset=360
# https://sofifa.com/players?offset=420
# https://sofifa.com/players?offset=480
# https://sofifa.com/players?offset=540

# %%
for i in range(0,600,60):
  url = f'https://sofifa.com/players?offset={i}'

# %%
sumit = [0, 60, 120, 180, 240, 300, 360, 420, 480, 540]

# %%
for i in sumit :
    print( f'https://sofifa.com/players?offset=0' )
# Out:
# https://sofifa.com/players?offset=0
# https://sofifa.com/players?offset=0
# https://sofifa.com/players?offset=0
# https://sofifa.com/players?offset=0
# https://sofifa.com/players?offset=0
# https://sofifa.com/players?offset=0
# https://sofifa.com/players?offset=0
# https://sofifa.com/players?offset=0
# https://sofifa.com/players?offset=0
# https://sofifa.com/players?offset=0

# %%
NAME = []
AGE = []
OVA = []
POT = []
TEAM_NAME = []
CONTRACT = []
VALUE = []
WAGE = []
TOTAL_STATS = []

# %%
for i in sumit :
  
    url = f'https://sofifa.com/players?offset={i}'
    sumitresp = rq.get( url )
    sumitsoup = BeautifulSoup( sumitresp.content , 'lxml' )
    sumit_data = sumitsoup.findAll('tbody', attrs = {'class': 'list'})
    
    for name in sumit_data :

        names = name.find('a', class_ = "tooltip").text
        NAME.append(names)

        age = name.find('td', class_= "col col-ae"  ).text.replace('\n', '')
        AGE.append(age)
        
        overall_rating = name.find('td', class_="col col-oa").text.replace('\n', '')
        OVA.append(overall_rating)
        
        potential = name.find('td', class_="col col-pt" ).text.replace('\n', '')
        POT.append(potential)
        
        team_name = name.find('div', attrs = {'class': 'bp3-text-overflow-ellipsis'}).text.replace('\n', '')
        TEAM_NAME.append(team_name)

        contract_year = name.find('div', class_ = "sub").text.replace('\n', '')
        CONTRACT.append(contract_year)

        value = name.find('td', class_ = "col col-vl").text.replace('\n', '')
        VALUE.append(value)

        wage = name.find('td', class_ = "col col-wg").text.replace('\n', '')
        WAGE.append(wage) 

        total_stats = name.find('span', class_ = "bp3-tag p").text.replace('\n', '')
        TOTAL_STATS.append(total_stats)

# %%
sumit01 = pd.DataFrame({"Name": NAME,
                   "Age": AGE,
                   "Overall_Rating": OVA,
                   "Potential": POT,
                   "Team_Name": TEAM_NAME,
                   "Contract_Year": CONTRACT,
                   "Value(M)": VALUE,
                   "Wage(K)": WAGE,
                   "Total_Stats": TOTAL_STATS})

# %%
sumit01.to_csv('sumitfifa.csv')

# %%
sumit01.to_excel("sumitfifaxp.xlsx")

# %%
type( sumit01 )
# Out:
# pandas.core.frame.DataFrame

# %%
sumit01
# Out:
#               Name Age Overall_Rating  ... Value(M) Wage(K) Total_Stats
# 0    A. Tchouaméni  21             80  ...   €42.5M    €43K        2104
# 1  Pedro Gonçalves  23             81  ...   €51.5M    €19K        2093
# 2      K. Demirbay  27             80  ...   €22.5M    €58K        2126
# 3       A. Danjuma  24             77  ...     €16M    €30K        1892
# 4        F. Bustos  25             77  ...     €13M    €14K        2024
# 5             Isco  29             82  ...     €30M   €175K        2060
# 6       P. Struijk  21             74  ...      €9M    €38K        1685
# 7         D. Payet  34             80  ...     €10M    €47K        1996
# 8    G. Di Lorenzo  27             80  ...   €20.5M    €63K        2112
# 9   Iñaki Williams  27             81  ...     €30M    €39K        2039
#
# [10 rows x 9 columns]

# %%
sumit01.ndim
# Out:
# 2

# %%
sumit01.shape
# Out:
# (10, 9)

# %%
sumit01.columns
# Out:
# Index(['Name', 'Age', 'Overall_Rating', 'Potential', 'Team_Name',
#        'Contract_Year', 'Value(M)', 'Wage(K)', 'Total_Stats'],
#       dtype='object')

# %%
sumit01.head(10)
# Out:
#               Name Age Overall_Rating  ... Value(M) Wage(K) Total_Stats
# 0    A. Tchouaméni  21             80  ...   €42.5M    €43K        2104
# 1  Pedro Gonçalves  23             81  ...   €51.5M    €19K        2093
# 2      K. Demirbay  27             80  ...   €22.5M    €58K        2126
# 3       A. Danjuma  24             77  ...     €16M    €30K        1892
# 4        F. Bustos  25             77  ...     €13M    €14K        2024
# 5             Isco  29             82  ...     €30M   €175K        2060
# 6       P. Struijk  21             74  ...      €9M    €38K        1685
# 7         D. Payet  34             80  ...     €10M    €47K        1996
# 8    G. Di Lorenzo  27             80  ...   €20.5M    €63K        2112
# 9   Iñaki Williams  27             81  ...     €30M    €39K        2039
#
# [10 rows x 9 columns]

# %%
sumit01.tail(10)
# Out:
#               Name Age Overall_Rating  ... Value(M) Wage(K) Total_Stats
# 0    A. Tchouaméni  21             80  ...   €42.5M    €43K        2104
# 1  Pedro Gonçalves  23             81  ...   €51.5M    €19K        2093
# 2      K. Demirbay  27             80  ...   €22.5M    €58K        2126
# 3       A. Danjuma  24             77  ...     €16M    €30K        1892
# 4        F. Bustos  25             77  ...     €13M    €14K        2024
# 5             Isco  29             82  ...     €30M   €175K        2060
# 6       P. Struijk  21             74  ...      €9M    €38K        1685
# 7         D. Payet  34             80  ...     €10M    €47K        1996
# 8    G. Di Lorenzo  27             80  ...   €20.5M    €63K        2112
# 9   Iñaki Williams  27             81  ...     €30M    €39K        2039
#
# [10 rows x 9 columns]

# %%
sumit01.describe()
# Out:
#              Name Age Overall_Rating  ... Value(M) Wage(K) Total_Stats
# count          10  10             10  ...       10      10          10
# unique         10   7              5  ...        9      10          10
# top     F. Bustos  27             80  ...     €30M    €14K        1685
# freq            1   3              4  ...        2       1           1
#
# [4 rows x 9 columns]

# %%
sumit01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            10 non-null     object
#  1   Age             10 non-null     object
#  2   Overall_Rating  10 non-null     object
#  3   Potential       10 non-null     object
#  4   Team_Name       10 non-null     object
#  5   Contract_Year   10 non-null     object
#  6   Value(M)        10 non-null     object
#  7   Wage(K)         10 non-null     object
#  8   Total_Stats     10 non-null     object
# dtypes: object(9)
# memory usage: 848.0+ bytes

# %%
sumit01.isnull().sum()
# Out:
# Name              0
# Age               0
# Overall_Rating    0
# Potential         0
# Team_Name         0
# Contract_Year     0
# Value(M)          0
# Wage(K)           0
# Total_Stats       0
# dtype: int64

# %%
sumit01.isnull().sum().sum()
# Out:
# 0

# %%
sns.heatmap(sumit01.isnull())

# %%
sumit01['Name'].value_counts()
# Out:
# F. Bustos          1
# Pedro Gonçalves    1
# A. Tchouaméni      1
# K. Demirbay        1
# Isco               1
# Iñaki Williams     1
# G. Di Lorenzo      1
# P. Struijk         1
# A. Danjuma         1
# D. Payet           1
# Name: Name, dtype: int64

# %%
sns.countplot('Name', data = sumit01)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
base_color = sns.color_palette()[ 1 ]
gen_order = sumit01['Name'].value_counts().index
sns.countplot( data = sumit01 , x = 'Name', color = base_color , order = gen_order )

# %%
sumit01['Age'].value_counts()
# Out:
# 27    3
# 21    2
# 29    1
# 25    1
# 23    1
# 34    1
# 24    1
# Name: Age, dtype: int64

# %%
sns.countplot('Age', data = sumit01)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
base_color = sns.color_palette()[ 2 ]
gen_order = sumit01['Age'].value_counts().index
sns.countplot( data = sumit01 , x = 'Age', color = base_color , order = gen_order )

# %%
sumit01['Overall_Rating'].value_counts()
# Out:
# 80    4
# 81    2
# 77    2
# 82    1
# 74    1
# Name: Overall_Rating, dtype: int64

# %%
sns.countplot('Overall_Rating', data = sumit01)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
base_color = sns.color_palette()[ 3 ]
gen_order = sumit01['Overall_Rating'].value_counts().index
sns.countplot( data = sumit01 , x = 'Overall_Rating', color = base_color , order = gen_order )

# %%
sumit01['Potential'].value_counts()
# Out:
# 80    4
# 82    3
# 87    1
# 83    1
# 88    1
# Name: Potential, dtype: int64

# %%
sns.countplot('Potential', data = sumit01)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
base_color = sns.color_palette()[ 4 ]
gen_order = sumit01['Potential'].value_counts().index
sns.countplot( data = sumit01 , x = 'Potential', color = base_color , order = gen_order )

# %%
sumit01['Team_Name'].value_counts()
# Out:
# F. Bustos          1
# Pedro Gonçalves    1
# A. Tchouaméni      1
# K. Demirbay        1
# Isco               1
# Iñaki Williams     1
# G. Di Lorenzo      1
# P. Struijk         1
# A. Danjuma         1
# D. Payet           1
# Name: Team_Name, dtype: int64

# %%
sns.countplot('Team_Name', data = sumit01)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
base_color = sns.color_palette()[ 5 ]
gen_order = sumit01['Team_Name'].value_counts().index
sns.countplot( data = sumit01 , x = 'Team_Name', color = base_color , order = gen_order )

# %%
sumit01['Contract_Year'].value_counts()
# Out:
# 2020 ~ 2025    1
# 2020 ~ 2024    1
# 2019 ~ 2024    1
# 2018 ~ 2024    1
# 2013 ~ 2022    1
# 2012 ~ 2028    1
# 2019 ~ 2026    1
# 2021 ~ 2026    1
# 2016 ~ 2022    1
# 2017 ~ 2024    1
# Name: Contract_Year, dtype: int64

# %%
sns.countplot('Contract_Year', data = sumit01)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
base_color = sns.color_palette()[ 6 ]
gen_order = sumit01['Contract_Year'].value_counts().index
sns.countplot( data = sumit01 , x = 'Contract_Year', color = base_color , order = gen_order )

# %%
sumit01['Value(M)'].value_counts()
# Out:
# €30M      2
# €42.5M    1
# €10M      1
# €13M      1
# €51.5M    1
# €16M      1
# €22.5M    1
# €9M       1
# €20.5M    1
# Name: Value(M), dtype: int64

# %%
sns.countplot('Value(M)', data = sumit01)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
base_color = sns.color_palette()[ 7 ]
gen_order = sumit01['Value(M)'].value_counts().index
sns.countplot( data = sumit01 , x = 'Value(M)', color = base_color , order = gen_order )

# %%
sumit01['Wage(K)'].value_counts()
# Out:
# €14K     1
# €43K     1
# €63K     1
# €58K     1
# €30K     1
# €175K    1
# €39K     1
# €47K     1
# €19K     1
# €38K     1
# Name: Wage(K), dtype: int64

# %%
sns.countplot('Wage(K)', data = sumit01)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
base_color = sns.color_palette()[ 8 ]
gen_order = sumit01['Wage(K)'].value_counts().index
sns.countplot( data = sumit01 , x = 'Wage(K)', color = base_color , order = gen_order )

# %%
sumit01['Total_Stats'].value_counts()
# Out:
# 1685    1
# 1892    1
# 2039    1
# 2112    1
# 2024    1
# 2104    1
# 2060    1
# 2093    1
# 1996    1
# 2126    1
# Name: Total_Stats, dtype: int64

# %%
sns.countplot('Total_Stats', data = sumit01)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
base_color = sns.color_palette()[ 9 ]
gen_order = sumit01['Total_Stats'].value_counts().index
sns.countplot( data = sumit01 , x = 'Total_Stats', color = base_color , order = gen_order )
